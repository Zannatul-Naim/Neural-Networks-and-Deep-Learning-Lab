# %% [markdown]
# # 1. VGG16

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

vgg_16_test = preprocess_input(x_test)
base_model_vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_vgg16.trainable = False

x = base_model_vgg16.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_vgg16 = Model(inputs=base_model_vgg16.input, outputs=output, name="VGG16")

model_vgg16.summary(show_trainable=True)

y_pred_probs = model_vgg16.predict(vgg_16_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_vgg16 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_vgg16:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 17s 0us/step
# Model: "VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer (InputLayer)    │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv1 (Conv2D)       │ (None, 224, 224, 64)  │      1,792 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv2 (Conv2D)       │ (None, 224, 224, 64)  │     36,928 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_pool (MaxPooling2D)  │ (None, 112, 112, 64)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv1 (Conv2D)       │ (None, 112, 112, 128) │     73,856 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv2 (Conv2D)       │ (None, 112, 112, 128) │    147,584 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_pool (MaxPooling2D)  │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv1 (Conv2D)       │ (None, 56, 56, 256)   │    295,168 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv2 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv3 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_pool (MaxPooling2D)  │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv1 (Conv2D)       │ (None, 28, 28, 512)   │  1,180,160 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv2 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv3 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_pool (MaxPooling2D)  │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv1 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv2 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv3 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_pool (MaxPooling2D)  │ (None, 7, 7, 512)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d    │ (None, 512)           │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense (Dense)               │ (None, 20)            │     10,260 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 14,724,948 (56.17 MB)
#  Trainable params: 10,260 (40.08 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step
# Accuracy: 0.0895

# %% [markdown]
# # 2. VGG19

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

model_vgg19 = VGG19
vgg_19_test = preprocess_input(x_test)
base_model_vgg19 = VGG19(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_vgg19.trainable = False

x = base_model_vgg19.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_vgg19 = Model(inputs=base_model_vgg19.input, outputs=output, name="VGG19")

model_vgg19.summary(show_trainable=True)

y_pred_probs = model_vgg19.predict(vgg_19_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_vgg19 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_vgg19:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 23s 0us/step
# Model: "VGG19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_1 (InputLayer)  │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv1 (Conv2D)       │ (None, 224, 224, 64)  │      1,792 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv2 (Conv2D)       │ (None, 224, 224, 64)  │     36,928 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_pool (MaxPooling2D)  │ (None, 112, 112, 64)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv1 (Conv2D)       │ (None, 112, 112, 128) │     73,856 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv2 (Conv2D)       │ (None, 112, 112, 128) │    147,584 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_pool (MaxPooling2D)  │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv1 (Conv2D)       │ (None, 56, 56, 256)   │    295,168 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv2 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv3 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv4 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_pool (MaxPooling2D)  │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv1 (Conv2D)       │ (None, 28, 28, 512)   │  1,180,160 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv2 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv3 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv4 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_pool (MaxPooling2D)  │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv1 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv2 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv3 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv4 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_pool (MaxPooling2D)  │ (None, 7, 7, 512)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ global_average_pooling2d_1  │ (None, 512)           │          0 │   -   │
# │ (GlobalAveragePooling2D)    │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_1 (Dense)             │ (None, 20)            │     10,260 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 20,034,644 (76.43 MB)
#  Trainable params: 10,260 (40.08 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 172s 3s/step
# Accuracy: 0.0310

# %% [markdown]
# # 3. Xception

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

model_xception = Xception
xception_test = preprocess_input(x_test)

base_model_xception = Xception(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_xception.trainable = False

x = base_model_xception.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_xception = Model(inputs=base_model_xception.input, outputs=output, name="Xception")

model_xception.summary(show_trainable=True)

y_pred_probs = model_xception.predict(xception_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_xception = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_xception:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 27s 0us/step
# Model: "Xception"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_2     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1      │ (None, 111,     │       864 │ input_layer_2… │   N   │
# │ (Conv2D)          │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_bn   │ (None, 111,     │       128 │ block1_conv1[… │   N   │
# │ (BatchNormalizat… │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_act  │ (None, 111,     │         0 │ block1_conv1_… │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2      │ (None, 109,     │    18,432 │ block1_conv1_… │   N   │
# │ (Conv2D)          │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_bn   │ (None, 109,     │       256 │ block1_conv2[… │   N   │
# │ (BatchNormalizat… │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_act  │ (None, 109,     │         0 │ block1_conv2_… │   -   │
# │ (Activation)      │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1   │ (None, 109,     │     8,768 │ block1_conv2_… │   N   │
# │ (SeparableConv2D) │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1_… │ (None, 109,     │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 109,     │         0 │ block2_sepcon… │   -   │
# │ (Activation)      │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2   │ (None, 109,     │    17,536 │ block2_sepcon… │   N   │
# │ (SeparableConv2D) │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 109,     │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d (Conv2D)   │ (None, 55, 55,  │     8,192 │ block1_conv2_… │   N   │
# │                   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_pool       │ (None, 55, 55,  │         0 │ block2_sepcon… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 55, 55,  │       512 │ conv2d[0][0]   │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add (Add)         │ (None, 55, 55,  │         0 │ block2_pool[0… │   -   │
# │                   │ 128)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 55, 55,  │         0 │ add[0][0]      │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1   │ (None, 55, 55,  │    33,920 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 55, 55,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 55, 55,  │         0 │ block3_sepcon… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2   │ (None, 55, 55,  │    67,840 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 55, 55,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_1 (Conv2D) │ (None, 28, 28,  │    32,768 │ add[0][0]      │   N   │
# │                   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_pool       │ (None, 28, 28,  │         0 │ block3_sepcon… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 28, 28,  │     1,024 │ conv2d_1[0][0] │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_1 (Add)       │ (None, 28, 28,  │         0 │ block3_pool[0… │   -   │
# │                   │ 256)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 28, 28,  │         0 │ add_1[0][0]    │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1   │ (None, 28, 28,  │   188,672 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 28, 28,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 28, 28,  │         0 │ block4_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2   │ (None, 28, 28,  │   536,536 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 28, 28,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_2 (Conv2D) │ (None, 14, 14,  │   186,368 │ add_1[0][0]    │   N   │
# │                   │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_pool       │ (None, 14, 14,  │         0 │ block4_sepcon… │   -   │
# │ (MaxPooling2D)    │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 14, 14,  │     2,912 │ conv2d_2[0][0] │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_2 (Add)       │ (None, 14, 14,  │         0 │ block4_pool[0… │   -   │
# │                   │ 728)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 14, 14,  │         0 │ add_2[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1   │ (None, 14, 14,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 14, 14,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 14, 14,  │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2   │ (None, 14, 14,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 14, 14,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 14, 14,  │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3   │ (None, 14, 14,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 14, 14,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_3 (Add)       │ (None, 14, 14,  │         0 │ block5_sepcon… │   -   │
# │                   │ 728)            │           │ add_2[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 14, 14,  │         0 │ add_3[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1   │ (None, 14, 14,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 14, 14,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 14, 14,  │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2   │ (None, 14, 14,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 14, 14,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 14, 14,  │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3   │ (None, 14, 14,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 14, 14,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_4 (Add)       │ (None, 14, 14,  │         0 │ block6_sepcon… │   -   │
# │                   │ 728)            │           │ add_3[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 14, 14,  │         0 │ add_4[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1   │ (None, 14, 14,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 14, 14,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 14, 14,  │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2   │ (None, 14, 14,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 14, 14,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 14, 14,  │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3   │ (None, 14, 14,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 14, 14,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_5 (Add)       │ (None, 14, 14,  │         0 │ block7_sepcon… │   -   │
# │                   │ 728)            │           │ add_4[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 14, 14,  │         0 │ add_5[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1   │ (None, 14, 14,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 14, 14,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 14, 14,  │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2   │ (None, 14, 14,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 14, 14,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 14, 14,  │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3   │ (None, 14, 14,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 14, 14,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_6 (Add)       │ (None, 14, 14,  │         0 │ block8_sepcon… │   -   │
# │                   │ 728)            │           │ add_5[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 14, 14,  │         0 │ add_6[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1   │ (None, 14, 14,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 14, 14,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 14, 14,  │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2   │ (None, 14, 14,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 14, 14,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 14, 14,  │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3   │ (None, 14, 14,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 14, 14,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_7 (Add)       │ (None, 14, 14,  │         0 │ block9_sepcon… │   -   │
# │                   │ 728)            │           │ add_6[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 14, 14,  │         0 │ add_7[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1  │ (None, 14, 14,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 14, 14,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 14, 14,  │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2  │ (None, 14, 14,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 14, 14,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 14, 14,  │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3  │ (None, 14, 14,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 14, 14,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_8 (Add)       │ (None, 14, 14,  │         0 │ block10_sepco… │   -   │
# │                   │ 728)            │           │ add_7[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 14, 14,  │         0 │ add_8[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1  │ (None, 14, 14,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 14, 14,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 14, 14,  │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2  │ (None, 14, 14,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 14, 14,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 14, 14,  │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3  │ (None, 14, 14,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 14, 14,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_9 (Add)       │ (None, 14, 14,  │         0 │ block11_sepco… │   -   │
# │                   │ 728)            │           │ add_8[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 14, 14,  │         0 │ add_9[0][0]    │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1  │ (None, 14, 14,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 14, 14,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 14, 14,  │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2  │ (None, 14, 14,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 14, 14,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 14, 14,  │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3  │ (None, 14, 14,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 14, 14,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_10 (Add)      │ (None, 14, 14,  │         0 │ block12_sepco… │   -   │
# │                   │ 728)            │           │ add_9[0][0]    │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 14, 14,  │         0 │ add_10[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1  │ (None, 14, 14,  │   536,536 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 14, 14,  │     2,912 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 14, 14,  │         0 │ block13_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2  │ (None, 14, 14,  │   752,024 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 14, 14,  │     4,096 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_3 (Conv2D) │ (None, 7, 7,    │   745,472 │ add_10[0][0]   │   N   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_pool      │ (None, 7, 7,    │         0 │ block13_sepco… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 7, 7,    │     4,096 │ conv2d_3[0][0] │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_11 (Add)      │ (None, 7, 7,    │         0 │ block13_pool[… │   -   │
# │                   │ 1024)           │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1  │ (None, 7, 7,    │ 1,582,080 │ add_11[0][0]   │   N   │
# │ (SeparableConv2D) │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 7, 7,    │     6,144 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 7, 7,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2  │ (None, 7, 7,    │ 3,159,552 │ block14_sepco… │   N   │
# │ (SeparableConv2D) │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 7, 7,    │     8,192 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 7, 7,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 2048)    │         0 │ block14_sepco… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_2 (Dense)   │ (None, 20)      │    40,980 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 20,902,460 (79.74 MB)
#  Trainable params: 40,980 (160.08 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step
# Accuracy: 0.0520

# %% [markdown]
# # 4. ResNet50

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

model_ResNet50 = ResNet50
ResNet50_test = preprocess_input(x_test)
base_model_ResNet50 = ResNet50(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_ResNet50.trainable = False

x = base_model_ResNet50.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_resnet50 = Model(inputs=base_model_ResNet50.input, outputs=output, name="ResNet50")

model_resnet50.summary(show_trainable=True)

y_pred_probs = model_resnet50.predict(ResNet50_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_resnet50 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_resnet50:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 28s 0us/step
# Model: "ResNet50"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_3     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_pad         │ (None, 230,     │         0 │ input_layer_3… │   -   │
# │ (ZeroPadding2D)   │ 230, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_conv        │ (None, 112,     │     9,472 │ conv1_pad[0][… │   N   │
# │ (Conv2D)          │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_bn          │ (None, 112,     │       256 │ conv1_conv[0]… │   N   │
# │ (BatchNormalizat… │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_relu        │ (None, 112,     │         0 │ conv1_bn[0][0] │   -   │
# │ (Activation)      │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1_pad         │ (None, 114,     │         0 │ conv1_relu[0]… │   -   │
# │ (ZeroPadding2D)   │ 114, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1_pool        │ (None, 56, 56,  │         0 │ pool1_pad[0][… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_c… │ (None, 56, 56,  │     4,160 │ pool1_pool[0]… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_bn │ (None, 56, 56,  │       256 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_c… │ (None, 56, 56,  │    36,928 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_bn │ (None, 56, 56,  │       256 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_c… │ (None, 56, 56,  │    16,640 │ pool1_pool[0]… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_bn │ (None, 56, 56,  │     1,024 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_3_bn │ (None, 56, 56,  │     1,024 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_add  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_out  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_c… │ (None, 56, 56,  │    16,448 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_bn │ (None, 56, 56,  │       256 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_c… │ (None, 56, 56,  │    36,928 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_bn │ (None, 56, 56,  │       256 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_3_bn │ (None, 56, 56,  │     1,024 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_add  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_out  │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_c… │ (None, 56, 56,  │    16,448 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_bn │ (None, 56, 56,  │       256 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_c… │ (None, 56, 56,  │    36,928 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_bn │ (None, 56, 56,  │       256 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_3_bn │ (None, 56, 56,  │     1,024 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_add  │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_out  │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_c… │ (None, 28, 28,  │    32,896 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_c… │ (None, 28, 28,  │   131,584 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_bn │ (None, 28, 28,  │     2,048 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_add  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_out  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_c… │ (None, 28, 28,  │    65,664 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_add  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_out  │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_c… │ (None, 28, 28,  │    65,664 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_add  │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_out  │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_c… │ (None, 28, 28,  │    65,664 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_add  │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_out  │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_c… │ (None, 14, 14,  │   131,328 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_c… │ (None, 14, 14,  │   525,312 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_bn │ (None, 14, 14,  │     4,096 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_add  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_out  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_add  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_out  │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_add  │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_out  │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_add  │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_out  │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_add  │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_out  │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_add  │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_out  │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_c… │ (None, 7, 7,    │   524,800 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_r… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_c… │ (None, 7, 7,    │ 2,359,808 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_r… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_0_c… │ (None, 7, 7,    │ 2,099,200 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_0_bn │ (None, 7, 7,    │     8,192 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_3_bn │ (None, 7, 7,    │     8,192 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_add  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_out  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_c… │ (None, 7, 7,    │ 1,049,088 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_r… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_c… │ (None, 7, 7,    │ 2,359,808 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_r… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_3_bn │ (None, 7, 7,    │     8,192 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_add  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_out  │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_c… │ (None, 7, 7,    │ 1,049,088 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_r… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_c… │ (None, 7, 7,    │ 2,359,808 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_r… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_3_bn │ (None, 7, 7,    │     8,192 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_add  │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_out  │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 2048)    │         0 │ conv5_block3_… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_3 (Dense)   │ (None, 20)      │    40,980 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 23,628,692 (90.14 MB)
#  Trainable params: 40,980 (160.08 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 60s 926ms/step
# Accuracy: 0.0725

# %% [markdown]
# # 5. ResNet50V2

# %%
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

model_ResNet50V2 = ResNet50V2
ResNet50V2_test = preprocess_input(x_test)
base_model_ResNet50V2 = ResNet50V2(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_ResNet50V2.trainable = False

x = base_model_ResNet50V2.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_resnet50v2 = Model(inputs=base_model_ResNet50V2.input, outputs=output, name="ResNet50V2")

model_resnet50v2.summary(show_trainable=True)

y_pred_probs = model_resnet50v2.predict(ResNet50V2_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_resnet50v2 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_resnet50v2:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 27s 0us/step
# Model: "ResNet50V2"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_4     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_pad         │ (None, 230,     │         0 │ input_layer_4… │   -   │
# │ (ZeroPadding2D)   │ 230, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_conv        │ (None, 112,     │     9,472 │ conv1_pad[0][… │   N   │
# │ (Conv2D)          │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1_pad         │ (None, 114,     │         0 │ conv1_conv[0]… │   -   │
# │ (ZeroPadding2D)   │ 114, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1_pool        │ (None, 56, 56,  │         0 │ pool1_pad[0][… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_pre… │ (None, 56, 56,  │       256 │ pool1_pool[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_pre… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_c… │ (None, 56, 56,  │     4,096 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_bn │ (None, 56, 56,  │       256 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_p… │ (None, 58, 58,  │         0 │ conv2_block1_… │   -   │
# │ (ZeroPadding2D)   │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_bn │ (None, 56, 56,  │       256 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_c… │ (None, 56, 56,  │    16,640 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_out  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_pre… │ (None, 56, 56,  │     1,024 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_pre… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_c… │ (None, 56, 56,  │    16,384 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_bn │ (None, 56, 56,  │       256 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_p… │ (None, 58, 58,  │         0 │ conv2_block2_… │   -   │
# │ (ZeroPadding2D)   │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_bn │ (None, 56, 56,  │       256 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_out  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_pre… │ (None, 56, 56,  │     1,024 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_pre… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_c… │ (None, 56, 56,  │    16,384 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_bn │ (None, 56, 56,  │       256 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_p… │ (None, 58, 58,  │         0 │ conv2_block3_… │   -   │
# │ (ZeroPadding2D)   │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_c… │ (None, 28, 28,  │    36,864 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_bn │ (None, 28, 28,  │       256 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_r… │ (None, 28, 28,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d     │ (None, 28, 28,  │         0 │ conv2_block2_… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_3_c… │ (None, 28, 28,  │    16,640 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_out  │ (None, 28, 28,  │         0 │ max_pooling2d… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_pre… │ (None, 28, 28,  │     1,024 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_pre… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_c… │ (None, 28, 28,  │    32,768 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_p… │ (None, 30, 30,  │         0 │ conv3_block1_… │   -   │
# │ (ZeroPadding2D)   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_c… │ (None, 28, 28,  │   147,456 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_c… │ (None, 28, 28,  │   131,584 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_out  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_pre… │ (None, 28, 28,  │     2,048 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_pre… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_c… │ (None, 28, 28,  │    65,536 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_p… │ (None, 30, 30,  │         0 │ conv3_block2_… │   -   │
# │ (ZeroPadding2D)   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_c… │ (None, 28, 28,  │   147,456 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_out  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_pre… │ (None, 28, 28,  │     2,048 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_pre… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_c… │ (None, 28, 28,  │    65,536 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_p… │ (None, 30, 30,  │         0 │ conv3_block3_… │   -   │
# │ (ZeroPadding2D)   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_c… │ (None, 28, 28,  │   147,456 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_out  │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_pre… │ (None, 28, 28,  │     2,048 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_pre… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_c… │ (None, 28, 28,  │    65,536 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_p… │ (None, 30, 30,  │         0 │ conv3_block4_… │   -   │
# │ (ZeroPadding2D)   │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_c… │ (None, 14, 14,  │   147,456 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_bn │ (None, 14, 14,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_r… │ (None, 14, 14,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_1   │ (None, 14, 14,  │         0 │ conv3_block3_… │   -   │
# │ (MaxPooling2D)    │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_3_c… │ (None, 14, 14,  │    66,048 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_out  │ (None, 14, 14,  │         0 │ max_pooling2d… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_pre… │ (None, 14, 14,  │     2,048 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_pre… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_c… │ (None, 14, 14,  │   131,072 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_p… │ (None, 16, 16,  │         0 │ conv4_block1_… │   -   │
# │ (ZeroPadding2D)   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_c… │ (None, 14, 14,  │   589,824 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_c… │ (None, 14, 14,  │   525,312 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_out  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_pre… │ (None, 14, 14,  │     4,096 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_pre… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_c… │ (None, 14, 14,  │   262,144 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_p… │ (None, 16, 16,  │         0 │ conv4_block2_… │   -   │
# │ (ZeroPadding2D)   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_c… │ (None, 14, 14,  │   589,824 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_out  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_pre… │ (None, 14, 14,  │     4,096 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_pre… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_c… │ (None, 14, 14,  │   262,144 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_p… │ (None, 16, 16,  │         0 │ conv4_block3_… │   -   │
# │ (ZeroPadding2D)   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_c… │ (None, 14, 14,  │   589,824 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_out  │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_pre… │ (None, 14, 14,  │     4,096 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_pre… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_c… │ (None, 14, 14,  │   262,144 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_p… │ (None, 16, 16,  │         0 │ conv4_block4_… │   -   │
# │ (ZeroPadding2D)   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_c… │ (None, 14, 14,  │   589,824 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_out  │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_pre… │ (None, 14, 14,  │     4,096 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_pre… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_c… │ (None, 14, 14,  │   262,144 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_p… │ (None, 16, 16,  │         0 │ conv4_block5_… │   -   │
# │ (ZeroPadding2D)   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_c… │ (None, 14, 14,  │   589,824 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_out  │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_pre… │ (None, 14, 14,  │     4,096 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_pre… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_c… │ (None, 14, 14,  │   262,144 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_p… │ (None, 16, 16,  │         0 │ conv4_block6_… │   -   │
# │ (ZeroPadding2D)   │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_c… │ (None, 7, 7,    │   589,824 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_bn │ (None, 7, 7,    │     1,024 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_r… │ (None, 7, 7,    │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_2   │ (None, 7, 7,    │         0 │ conv4_block5_… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_3_c… │ (None, 7, 7,    │   263,168 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_out  │ (None, 7, 7,    │         0 │ max_pooling2d… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_pre… │ (None, 7, 7,    │     4,096 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_pre… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_c… │ (None, 7, 7,    │   524,288 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_r… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_p… │ (None, 9, 9,    │         0 │ conv5_block1_… │   -   │
# │ (ZeroPadding2D)   │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_c… │ (None, 7, 7,    │ 2,359,296 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_r… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_0_c… │ (None, 7, 7,    │ 2,099,200 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_out  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_pre… │ (None, 7, 7,    │     8,192 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_pre… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_c… │ (None, 7, 7,    │ 1,048,576 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_r… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_p… │ (None, 9, 9,    │         0 │ conv5_block2_… │   -   │
# │ (ZeroPadding2D)   │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_c… │ (None, 7, 7,    │ 2,359,296 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_r… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_out  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_pre… │ (None, 7, 7,    │     8,192 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_pre… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_c… │ (None, 7, 7,    │ 1,048,576 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_r… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_p… │ (None, 9, 9,    │         0 │ conv5_block3_… │   -   │
# │ (ZeroPadding2D)   │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_c… │ (None, 7, 7,    │ 2,359,296 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_r… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_out  │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ post_bn           │ (None, 7, 7,    │     8,192 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ post_relu         │ (None, 7, 7,    │         0 │ post_bn[0][0]  │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 2048)    │         0 │ post_relu[0][… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_4 (Dense)   │ (None, 20)      │    40,980 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 23,605,780 (90.05 MB)
#  Trainable params: 40,980 (160.08 KB)
#  Non-trainable params: 23,564,800 (89.89 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 810ms/step
# Accuracy: 0.0700

# %% [markdown]
# # 6. InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

model_inceptionv3 = InceptionV3
inception_test = preprocess_input(x_test)
base_model_inceptionv3 = InceptionV3(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_inceptionv3.trainable = False

x = base_model_inceptionv3.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_inceptionv3 = Model(inputs=base_model_inceptionv3.input, outputs=output, name="InceptionV3")

model_inceptionv3.summary(show_trainable=True)

y_pred_probs = model_inceptionv3.predict(inception_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_inceptionv3 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_inceptionv3:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 25s 0us/step
# Model: "InceptionV3"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_5     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_4 (Conv2D) │ (None, 111,     │       864 │ input_layer_5… │   N   │
# │                   │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 111,     │        96 │ conv2d_4[0][0] │   N   │
# │ (BatchNormalizat… │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation        │ (None, 111,     │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_5 (Conv2D) │ (None, 109,     │     9,216 │ activation[0]… │   N   │
# │                   │ 109, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 109,     │        96 │ conv2d_5[0][0] │   N   │
# │ (BatchNormalizat… │ 109, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_1      │ (None, 109,     │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 109, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_6 (Conv2D) │ (None, 109,     │    18,432 │ activation_1[… │   N   │
# │                   │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 109,     │       192 │ conv2d_6[0][0] │   N   │
# │ (BatchNormalizat… │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_2      │ (None, 109,     │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_3   │ (None, 54, 54,  │         0 │ activation_2[… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_7 (Conv2D) │ (None, 54, 54,  │     5,120 │ max_pooling2d… │   N   │
# │                   │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 54, 54,  │       240 │ conv2d_7[0][0] │   N   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_3      │ (None, 54, 54,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_8 (Conv2D) │ (None, 52, 52,  │   138,240 │ activation_3[… │   N   │
# │                   │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 52, 52,  │       576 │ conv2d_8[0][0] │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_4      │ (None, 52, 52,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_4   │ (None, 25, 25,  │         0 │ activation_4[… │   -   │
# │ (MaxPooling2D)    │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_12         │ (None, 25, 25,  │    12,288 │ max_pooling2d… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_12[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_8      │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_10         │ (None, 25, 25,  │     9,216 │ max_pooling2d… │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_13         │ (None, 25, 25,  │    55,296 │ activation_8[… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       144 │ conv2d_10[0][… │   N   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_13[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_6      │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_9      │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2d │ (None, 25, 25,  │         0 │ max_pooling2d… │   -   │
# │ (AveragePooling2… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_9 (Conv2D) │ (None, 25, 25,  │    12,288 │ max_pooling2d… │   N   │
# │                   │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_11         │ (None, 25, 25,  │    76,800 │ activation_6[… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_14         │ (None, 25, 25,  │    82,944 │ activation_9[… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_15         │ (None, 25, 25,  │     6,144 │ average_pooli… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_9[0][0] │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_11[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_14[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │        96 │ conv2d_15[0][… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_5      │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_7      │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_10     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_11     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed0            │ (None, 25, 25,  │         0 │ activation_5[… │   -   │
# │ (Concatenate)     │ 256)            │           │ activation_7[… │       │
# │                   │                 │           │ activation_10… │       │
# │                   │                 │           │ activation_11… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_19         │ (None, 25, 25,  │    16,384 │ mixed0[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_19[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_15     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_17         │ (None, 25, 25,  │    12,288 │ mixed0[0][0]   │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_20         │ (None, 25, 25,  │    55,296 │ activation_15… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       144 │ conv2d_17[0][… │   N   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_20[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_13     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_16     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 25, 25,  │         0 │ mixed0[0][0]   │   -   │
# │ (AveragePooling2… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_16         │ (None, 25, 25,  │    16,384 │ mixed0[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_18         │ (None, 25, 25,  │    76,800 │ activation_13… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_21         │ (None, 25, 25,  │    82,944 │ activation_16… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_22         │ (None, 25, 25,  │    16,384 │ average_pooli… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_16[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_18[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_21[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_22[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_12     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_14     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_17     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_18     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed1            │ (None, 25, 25,  │         0 │ activation_12… │   -   │
# │ (Concatenate)     │ 288)            │           │ activation_14… │       │
# │                   │                 │           │ activation_17… │       │
# │                   │                 │           │ activation_18… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_26         │ (None, 25, 25,  │    18,432 │ mixed1[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_26[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_22     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_24         │ (None, 25, 25,  │    13,824 │ mixed1[0][0]   │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_27         │ (None, 25, 25,  │    55,296 │ activation_22… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       144 │ conv2d_24[0][… │   N   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_27[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_20     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_23     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 25, 25,  │         0 │ mixed1[0][0]   │   -   │
# │ (AveragePooling2… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_23         │ (None, 25, 25,  │    18,432 │ mixed1[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_25         │ (None, 25, 25,  │    76,800 │ activation_20… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_28         │ (None, 25, 25,  │    82,944 │ activation_23… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_29         │ (None, 25, 25,  │    18,432 │ average_pooli… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_23[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_25[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_28[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_29[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_19     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_21     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_24     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_25     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed2            │ (None, 25, 25,  │         0 │ activation_19… │   -   │
# │ (Concatenate)     │ 288)            │           │ activation_21… │       │
# │                   │                 │           │ activation_24… │       │
# │                   │                 │           │ activation_25… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_31         │ (None, 25, 25,  │    18,432 │ mixed2[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_31[0][… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_27     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_32         │ (None, 25, 25,  │    55,296 │ activation_27… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_32[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_28     │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_30         │ (None, 12, 12,  │   995,328 │ mixed2[0][0]   │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_33         │ (None, 12, 12,  │    82,944 │ activation_28… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │     1,152 │ conv2d_30[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       288 │ conv2d_33[0][… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_26     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_29     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_5   │ (None, 12, 12,  │         0 │ mixed2[0][0]   │   -   │
# │ (MaxPooling2D)    │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed3            │ (None, 12, 12,  │         0 │ activation_26… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_29… │       │
# │                   │                 │           │ max_pooling2d… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_38         │ (None, 12, 12,  │    98,304 │ mixed3[0][0]   │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_38[0][… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_34     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_39         │ (None, 12, 12,  │   114,688 │ activation_34… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_39[0][… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_35     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_35         │ (None, 12, 12,  │    98,304 │ mixed3[0][0]   │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_40         │ (None, 12, 12,  │   114,688 │ activation_35… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_35[0][… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_40[0][… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_31     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_36     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_36         │ (None, 12, 12,  │   114,688 │ activation_31… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_41         │ (None, 12, 12,  │   114,688 │ activation_36… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_36[0][… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_41[0][… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_32     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_37     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 12, 12,  │         0 │ mixed3[0][0]   │   -   │
# │ (AveragePooling2… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_34         │ (None, 12, 12,  │   147,456 │ mixed3[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_37         │ (None, 12, 12,  │   172,032 │ activation_32… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_42         │ (None, 12, 12,  │   172,032 │ activation_37… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_43         │ (None, 12, 12,  │   147,456 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_34[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_37[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_42[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_43[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_30     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_33     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_38     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_39     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed4            │ (None, 12, 12,  │         0 │ activation_30… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_33… │       │
# │                   │                 │           │ activation_38… │       │
# │                   │                 │           │ activation_39… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_48         │ (None, 12, 12,  │   122,880 │ mixed4[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_48[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_44     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_49         │ (None, 12, 12,  │   179,200 │ activation_44… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_49[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_45     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_45         │ (None, 12, 12,  │   122,880 │ mixed4[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_50         │ (None, 12, 12,  │   179,200 │ activation_45… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_45[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_50[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_41     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_46     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_46         │ (None, 12, 12,  │   179,200 │ activation_41… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_51         │ (None, 12, 12,  │   179,200 │ activation_46… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_46[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_51[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_42     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_47     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 12, 12,  │         0 │ mixed4[0][0]   │   -   │
# │ (AveragePooling2… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_44         │ (None, 12, 12,  │   147,456 │ mixed4[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_47         │ (None, 12, 12,  │   215,040 │ activation_42… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_52         │ (None, 12, 12,  │   215,040 │ activation_47… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_53         │ (None, 12, 12,  │   147,456 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_44[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_47[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_52[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_53[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_40     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_43     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_48     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_49     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed5            │ (None, 12, 12,  │         0 │ activation_40… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_43… │       │
# │                   │                 │           │ activation_48… │       │
# │                   │                 │           │ activation_49… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_58         │ (None, 12, 12,  │   122,880 │ mixed5[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_58[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_54     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_59         │ (None, 12, 12,  │   179,200 │ activation_54… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_59[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_55     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_55         │ (None, 12, 12,  │   122,880 │ mixed5[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_60         │ (None, 12, 12,  │   179,200 │ activation_55… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_55[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_60[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_51     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_56     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_56         │ (None, 12, 12,  │   179,200 │ activation_51… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_61         │ (None, 12, 12,  │   179,200 │ activation_56… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_56[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_61[0][… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_52     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_57     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 12, 12,  │         0 │ mixed5[0][0]   │   -   │
# │ (AveragePooling2… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_54         │ (None, 12, 12,  │   147,456 │ mixed5[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_57         │ (None, 12, 12,  │   215,040 │ activation_52… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_62         │ (None, 12, 12,  │   215,040 │ activation_57… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_63         │ (None, 12, 12,  │   147,456 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_54[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_57[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_62[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_63[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_50     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_53     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_58     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_59     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed6            │ (None, 12, 12,  │         0 │ activation_50… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_53… │       │
# │                   │                 │           │ activation_58… │       │
# │                   │                 │           │ activation_59… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_68         │ (None, 12, 12,  │   147,456 │ mixed6[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_68[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_64     │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_69         │ (None, 12, 12,  │   258,048 │ activation_64… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_69[0][… │   N   │
# ...
# │ activation_75     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_6   │ (None, 5, 5,    │         0 │ mixed7[0][0]   │   -   │
# │ (MaxPooling2D)    │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed8            │ (None, 5, 5,    │         0 │ activation_71… │   -   │
# │ (Concatenate)     │ 1280)           │           │ activation_75… │       │
# │                   │                 │           │ max_pooling2d… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_84         │ (None, 5, 5,    │   573,440 │ mixed8[0][0]   │   N   │
# │ (Conv2D)          │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,344 │ conv2d_84[0][… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_80     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_81         │ (None, 5, 5,    │   491,520 │ mixed8[0][0]   │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_85         │ (None, 5, 5,    │ 1,548,288 │ activation_80… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_81[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_85[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_77     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_81     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_82         │ (None, 5, 5,    │   442,368 │ activation_77… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_83         │ (None, 5, 5,    │   442,368 │ activation_77… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_86         │ (None, 5, 5,    │   442,368 │ activation_81… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_87         │ (None, 5, 5,    │   442,368 │ activation_81… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 5, 5,    │         0 │ mixed8[0][0]   │   -   │
# │ (AveragePooling2… │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_80         │ (None, 5, 5,    │   409,600 │ mixed8[0][0]   │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_82[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_83[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_86[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_87[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_88         │ (None, 5, 5,    │   245,760 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       960 │ conv2d_80[0][… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_78     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_79     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_82     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_83     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       576 │ conv2d_88[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_76     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed9_0          │ (None, 5, 5,    │         0 │ activation_78… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_79… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate       │ (None, 5, 5,    │         0 │ activation_82… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_83… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_84     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed9            │ (None, 5, 5,    │         0 │ activation_76… │   -   │
# │ (Concatenate)     │ 2048)           │           │ mixed9_0[0][0… │       │
# │                   │                 │           │ concatenate[0… │       │
# │                   │                 │           │ activation_84… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_93         │ (None, 5, 5,    │   917,504 │ mixed9[0][0]   │   N   │
# │ (Conv2D)          │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,344 │ conv2d_93[0][… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_89     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_90         │ (None, 5, 5,    │   786,432 │ mixed9[0][0]   │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_94         │ (None, 5, 5,    │ 1,548,288 │ activation_89… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_90[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_94[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_86     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_90     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_91         │ (None, 5, 5,    │   442,368 │ activation_86… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_92         │ (None, 5, 5,    │   442,368 │ activation_86… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_95         │ (None, 5, 5,    │   442,368 │ activation_90… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_96         │ (None, 5, 5,    │   442,368 │ activation_90… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 5, 5,    │         0 │ mixed9[0][0]   │   -   │
# │ (AveragePooling2… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_89         │ (None, 5, 5,    │   655,360 │ mixed9[0][0]   │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_91[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_92[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_95[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_96[0][… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_97         │ (None, 5, 5,    │   393,216 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       960 │ conv2d_89[0][… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_87     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_88     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_91     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_92     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       576 │ conv2d_97[0][… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_85     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed9_1          │ (None, 5, 5,    │         0 │ activation_87… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_88… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_1     │ (None, 5, 5,    │         0 │ activation_91… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_92… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_93     │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed10           │ (None, 5, 5,    │         0 │ activation_85… │   -   │
# │ (Concatenate)     │ 2048)           │           │ mixed9_1[0][0… │       │
# │                   │                 │           │ concatenate_1… │       │
# │                   │                 │           │ activation_93… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 2048)    │         0 │ mixed10[0][0]  │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_5 (Dense)   │ (None, 20)      │    40,980 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 21,843,764 (83.33 MB)
#  Trainable params: 40,980 (160.08 KB)
#  Non-trainable params: 21,802,784 (83.17 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 548ms/step
# Accuracy: 0.0430

# %% [markdown]
# # 7. MobileNetV2

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

mobileNetV2_test = preprocess_input(x_test)
base_model_mobileNetV2 = MobileNetV2(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_mobileNetV2.trainable = False

x = base_model_mobileNetV2.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_mobilenetV2 = Model(inputs=base_model_mobileNetV2.input, outputs=output, name="MobileNetV2")

model_mobilenetV2.summary(show_trainable=True)

y_pred_probs = model_mobilenetV2.predict(mobileNetV2_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_mobilenetv2 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_mobilenetv2:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_6     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv1 (Conv2D)    │ (None, 112,     │       864 │ input_layer_6… │   N   │
# │                   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bn_Conv1          │ (None, 112,     │       128 │ Conv1[0][0]    │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv1_relu (ReLU) │ (None, 112,     │         0 │ bn_Conv1[0][0] │   -   │
# │                   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │       288 │ Conv1_relu[0]… │   N   │
# │ (DepthwiseConv2D) │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │       128 │ expanded_conv… │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │         0 │ expanded_conv… │   -   │
# │ (ReLU)            │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 112,     │       512 │ expanded_conv… │   N   │
# │ (Conv2D)          │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 112,     │        64 │ expanded_conv… │   N   │
# │ (BatchNormalizat… │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand    │ (None, 112,     │     1,536 │ expanded_conv… │   N   │
# │ (Conv2D)          │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand_BN │ (None, 112,     │       384 │ block_1_expan… │   N   │
# │ (BatchNormalizat… │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand_r… │ (None, 112,     │         0 │ block_1_expan… │   -   │
# │ (ReLU)            │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_pad       │ (None, 113,     │         0 │ block_1_expan… │   -   │
# │ (ZeroPadding2D)   │ 113, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwise │ (None, 56, 56,  │       864 │ block_1_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwis… │ (None, 56, 56,  │       384 │ block_1_depth… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwis… │ (None, 56, 56,  │         0 │ block_1_depth… │   -   │
# │ (ReLU)            │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_project   │ (None, 56, 56,  │     2,304 │ block_1_depth… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_project_… │ (None, 56, 56,  │        96 │ block_1_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand    │ (None, 56, 56,  │     3,456 │ block_1_proje… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand_BN │ (None, 56, 56,  │       576 │ block_2_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand_r… │ (None, 56, 56,  │         0 │ block_2_expan… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwise │ (None, 56, 56,  │     1,296 │ block_2_expan… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwis… │ (None, 56, 56,  │       576 │ block_2_depth… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwis… │ (None, 56, 56,  │         0 │ block_2_depth… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_project   │ (None, 56, 56,  │     3,456 │ block_2_depth… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_project_… │ (None, 56, 56,  │        96 │ block_2_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_add (Add) │ (None, 56, 56,  │         0 │ block_1_proje… │   -   │
# │                   │ 24)             │           │ block_2_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand    │ (None, 56, 56,  │     3,456 │ block_2_add[0… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand_BN │ (None, 56, 56,  │       576 │ block_3_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand_r… │ (None, 56, 56,  │         0 │ block_3_expan… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_pad       │ (None, 57, 57,  │         0 │ block_3_expan… │   -   │
# │ (ZeroPadding2D)   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwise │ (None, 28, 28,  │     1,296 │ block_3_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwis… │ (None, 28, 28,  │       576 │ block_3_depth… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwis… │ (None, 28, 28,  │         0 │ block_3_depth… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_project   │ (None, 28, 28,  │     4,608 │ block_3_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_project_… │ (None, 28, 28,  │       128 │ block_3_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand    │ (None, 28, 28,  │     6,144 │ block_3_proje… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand_BN │ (None, 28, 28,  │       768 │ block_4_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand_r… │ (None, 28, 28,  │         0 │ block_4_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwise │ (None, 28, 28,  │     1,728 │ block_4_expan… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwis… │ (None, 28, 28,  │       768 │ block_4_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwis… │ (None, 28, 28,  │         0 │ block_4_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_project   │ (None, 28, 28,  │     6,144 │ block_4_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_project_… │ (None, 28, 28,  │       128 │ block_4_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_add (Add) │ (None, 28, 28,  │         0 │ block_3_proje… │   -   │
# │                   │ 32)             │           │ block_4_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand    │ (None, 28, 28,  │     6,144 │ block_4_add[0… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand_BN │ (None, 28, 28,  │       768 │ block_5_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand_r… │ (None, 28, 28,  │         0 │ block_5_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwise │ (None, 28, 28,  │     1,728 │ block_5_expan… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwis… │ (None, 28, 28,  │       768 │ block_5_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwis… │ (None, 28, 28,  │         0 │ block_5_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_project   │ (None, 28, 28,  │     6,144 │ block_5_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_project_… │ (None, 28, 28,  │       128 │ block_5_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_add (Add) │ (None, 28, 28,  │         0 │ block_4_add[0… │   -   │
# │                   │ 32)             │           │ block_5_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand    │ (None, 28, 28,  │     6,144 │ block_5_add[0… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand_BN │ (None, 28, 28,  │       768 │ block_6_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand_r… │ (None, 28, 28,  │         0 │ block_6_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_pad       │ (None, 29, 29,  │         0 │ block_6_expan… │   -   │
# │ (ZeroPadding2D)   │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwise │ (None, 14, 14,  │     1,728 │ block_6_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwis… │ (None, 14, 14,  │       768 │ block_6_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwis… │ (None, 14, 14,  │         0 │ block_6_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_project   │ (None, 14, 14,  │    12,288 │ block_6_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_project_… │ (None, 14, 14,  │       256 │ block_6_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand    │ (None, 14, 14,  │    24,576 │ block_6_proje… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand_BN │ (None, 14, 14,  │     1,536 │ block_7_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand_r… │ (None, 14, 14,  │         0 │ block_7_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwise │ (None, 14, 14,  │     3,456 │ block_7_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwis… │ (None, 14, 14,  │     1,536 │ block_7_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwis… │ (None, 14, 14,  │         0 │ block_7_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_project   │ (None, 14, 14,  │    24,576 │ block_7_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_project_… │ (None, 14, 14,  │       256 │ block_7_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_add (Add) │ (None, 14, 14,  │         0 │ block_6_proje… │   -   │
# │                   │ 64)             │           │ block_7_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand    │ (None, 14, 14,  │    24,576 │ block_7_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand_BN │ (None, 14, 14,  │     1,536 │ block_8_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand_r… │ (None, 14, 14,  │         0 │ block_8_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwise │ (None, 14, 14,  │     3,456 │ block_8_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwis… │ (None, 14, 14,  │     1,536 │ block_8_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwis… │ (None, 14, 14,  │         0 │ block_8_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_project   │ (None, 14, 14,  │    24,576 │ block_8_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_project_… │ (None, 14, 14,  │       256 │ block_8_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_add (Add) │ (None, 14, 14,  │         0 │ block_7_add[0… │   -   │
# │                   │ 64)             │           │ block_8_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand    │ (None, 14, 14,  │    24,576 │ block_8_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand_BN │ (None, 14, 14,  │     1,536 │ block_9_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand_r… │ (None, 14, 14,  │         0 │ block_9_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwise │ (None, 14, 14,  │     3,456 │ block_9_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwis… │ (None, 14, 14,  │     1,536 │ block_9_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwis… │ (None, 14, 14,  │         0 │ block_9_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_project   │ (None, 14, 14,  │    24,576 │ block_9_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_project_… │ (None, 14, 14,  │       256 │ block_9_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_add (Add) │ (None, 14, 14,  │         0 │ block_8_add[0… │   -   │
# │                   │ 64)             │           │ block_9_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand   │ (None, 14, 14,  │    24,576 │ block_9_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand_… │ (None, 14, 14,  │     1,536 │ block_10_expa… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand_… │ (None, 14, 14,  │         0 │ block_10_expa… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │     3,456 │ block_10_expa… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │     1,536 │ block_10_dept… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │         0 │ block_10_dept… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_project  │ (None, 14, 14,  │    36,864 │ block_10_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_project… │ (None, 14, 14,  │       384 │ block_10_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand   │ (None, 14, 14,  │    55,296 │ block_10_proj… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand_… │ (None, 14, 14,  │     2,304 │ block_11_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand_… │ (None, 14, 14,  │         0 │ block_11_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │     5,184 │ block_11_expa… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │     2,304 │ block_11_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │         0 │ block_11_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_project  │ (None, 14, 14,  │    55,296 │ block_11_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_project… │ (None, 14, 14,  │       384 │ block_11_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_add      │ (None, 14, 14,  │         0 │ block_10_proj… │   -   │
# │ (Add)             │ 96)             │           │ block_11_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand   │ (None, 14, 14,  │    55,296 │ block_11_add[… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand_… │ (None, 14, 14,  │     2,304 │ block_12_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand_… │ (None, 14, 14,  │         0 │ block_12_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │     5,184 │ block_12_expa… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │     2,304 │ block_12_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │         0 │ block_12_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_project  │ (None, 14, 14,  │    55,296 │ block_12_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_project… │ (None, 14, 14,  │       384 │ block_12_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_add      │ (None, 14, 14,  │         0 │ block_11_add[… │   -   │
# │ (Add)             │ 96)             │           │ block_12_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand   │ (None, 14, 14,  │    55,296 │ block_12_add[… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand_… │ (None, 14, 14,  │     2,304 │ block_13_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand_… │ (None, 14, 14,  │         0 │ block_13_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_pad      │ (None, 15, 15,  │         0 │ block_13_expa… │   -   │
# │ (ZeroPadding2D)   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │     5,184 │ block_13_pad[… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │     2,304 │ block_13_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │         0 │ block_13_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_project  │ (None, 7, 7,    │    92,160 │ block_13_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_project… │ (None, 7, 7,    │       640 │ block_13_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand   │ (None, 7, 7,    │   153,600 │ block_13_proj… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand_… │ (None, 7, 7,    │     3,840 │ block_14_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand_… │ (None, 7, 7,    │         0 │ block_14_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │     8,640 │ block_14_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │     3,840 │ block_14_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │         0 │ block_14_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_project  │ (None, 7, 7,    │   153,600 │ block_14_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_project… │ (None, 7, 7,    │       640 │ block_14_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_add      │ (None, 7, 7,    │         0 │ block_13_proj… │   -   │
# │ (Add)             │ 160)            │           │ block_14_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand   │ (None, 7, 7,    │   153,600 │ block_14_add[… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand_… │ (None, 7, 7,    │     3,840 │ block_15_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand_… │ (None, 7, 7,    │         0 │ block_15_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │     8,640 │ block_15_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │     3,840 │ block_15_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │         0 │ block_15_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_project  │ (None, 7, 7,    │   153,600 │ block_15_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_project… │ (None, 7, 7,    │       640 │ block_15_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_add      │ (None, 7, 7,    │         0 │ block_14_add[… │   -   │
# │ (Add)             │ 160)            │           │ block_15_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand   │ (None, 7, 7,    │   153,600 │ block_15_add[… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand_… │ (None, 7, 7,    │     3,840 │ block_16_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand_… │ (None, 7, 7,    │         0 │ block_16_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │     8,640 │ block_16_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │     3,840 │ block_16_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │         0 │ block_16_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_project  │ (None, 7, 7,    │   307,200 │ block_16_dept… │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_project… │ (None, 7, 7,    │     1,280 │ block_16_proj… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv_1 (Conv2D)   │ (None, 7, 7,    │   409,600 │ block_16_proj… │   N   │
# │                   │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv_1_bn         │ (None, 7, 7,    │     5,120 │ Conv_1[0][0]   │   N   │
# │ (BatchNormalizat… │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ out_relu (ReLU)   │ (None, 7, 7,    │         0 │ Conv_1_bn[0][… │   -   │
# │                   │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 1280)    │         0 │ out_relu[0][0] │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_6 (Dense)   │ (None, 20)      │    25,620 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 2,283,604 (8.71 MB)
#  Trainable params: 25,620 (100.08 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 365ms/step
# Accuracy: 0.0260

# %% [markdown]
# # 8. EfficientNetB0

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

model_EfficientNetB0 = EfficientNetB0
EfficientNetB0_test = preprocess_input(x_test)
base_model_EfficientNetB0 = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_EfficientNetB0.trainable = False

x = base_model_EfficientNetB0.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_efficientNetB0 = Model(inputs=base_model_EfficientNetB0.input, outputs=output, name="EfficientNetB0")

model_efficientNetB0.summary(show_trainable=True)

y_pred_probs = model_efficientNetB0.predict(EfficientNetB0_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_efficientnetb0 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_efficientnetb0:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "EfficientNetB0"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_7     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ rescaling         │ (None, 224,     │         0 │ input_layer_7… │   -   │
# │ (Rescaling)       │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normalization     │ (None, 224,     │         7 │ rescaling[0][… │   N   │
# │ (Normalization)   │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ rescaling_1       │ (None, 224,     │         0 │ normalization… │   -   │
# │ (Rescaling)       │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_conv_pad     │ (None, 225,     │         0 │ rescaling_1[0… │   -   │
# │ (ZeroPadding2D)   │ 225, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_conv         │ (None, 112,     │       864 │ stem_conv_pad… │   N   │
# │ (Conv2D)          │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_bn           │ (None, 112,     │       128 │ stem_conv[0][… │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_activation   │ (None, 112,     │         0 │ stem_bn[0][0]  │   -   │
# │ (Activation)      │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_dwconv    │ (None, 112,     │       288 │ stem_activati… │   N   │
# │ (DepthwiseConv2D) │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_bn        │ (None, 112,     │       128 │ block1a_dwcon… │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_activati… │ (None, 112,     │         0 │ block1a_bn[0]… │   -   │
# │ (Activation)      │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_se_squee… │ (None, 32)      │         0 │ block1a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_se_resha… │ (None, 1, 1,    │         0 │ block1a_se_sq… │   -   │
# │ (Reshape)         │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_se_reduce │ (None, 1, 1, 8) │       264 │ block1a_se_re… │   N   │
# │ (Conv2D)          │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_se_expand │ (None, 1, 1,    │       288 │ block1a_se_re… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_se_excite │ (None, 112,     │         0 │ block1a_activ… │   -   │
# │ (Multiply)        │ 112, 32)        │           │ block1a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_project_… │ (None, 112,     │       512 │ block1a_se_ex… │   N   │
# │ (Conv2D)          │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_project_… │ (None, 112,     │        64 │ block1a_proje… │   N   │
# │ (BatchNormalizat… │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_expand_c… │ (None, 112,     │     1,536 │ block1a_proje… │   N   │
# │ (Conv2D)          │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_expand_bn │ (None, 112,     │       384 │ block2a_expan… │   N   │
# │ (BatchNormalizat… │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_expand_a… │ (None, 112,     │         0 │ block2a_expan… │   -   │
# │ (Activation)      │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_dwconv_p… │ (None, 113,     │         0 │ block2a_expan… │   -   │
# │ (ZeroPadding2D)   │ 113, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_dwconv    │ (None, 56, 56,  │       864 │ block2a_dwcon… │   N   │
# │ (DepthwiseConv2D) │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_bn        │ (None, 56, 56,  │       384 │ block2a_dwcon… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_activati… │ (None, 56, 56,  │         0 │ block2a_bn[0]… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_se_squee… │ (None, 96)      │         0 │ block2a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_se_resha… │ (None, 1, 1,    │         0 │ block2a_se_sq… │   -   │
# │ (Reshape)         │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_se_reduce │ (None, 1, 1, 4) │       388 │ block2a_se_re… │   N   │
# │ (Conv2D)          │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_se_expand │ (None, 1, 1,    │       480 │ block2a_se_re… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_se_excite │ (None, 56, 56,  │         0 │ block2a_activ… │   -   │
# │ (Multiply)        │ 96)             │           │ block2a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_project_… │ (None, 56, 56,  │     2,304 │ block2a_se_ex… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_project_… │ (None, 56, 56,  │        96 │ block2a_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_expand_c… │ (None, 56, 56,  │     3,456 │ block2a_proje… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_expand_bn │ (None, 56, 56,  │       576 │ block2b_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_expand_a… │ (None, 56, 56,  │         0 │ block2b_expan… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_dwconv    │ (None, 56, 56,  │     1,296 │ block2b_expan… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_bn        │ (None, 56, 56,  │       576 │ block2b_dwcon… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_activati… │ (None, 56, 56,  │         0 │ block2b_bn[0]… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_se_squee… │ (None, 144)     │         0 │ block2b_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_se_resha… │ (None, 1, 1,    │         0 │ block2b_se_sq… │   -   │
# │ (Reshape)         │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_se_reduce │ (None, 1, 1, 6) │       870 │ block2b_se_re… │   N   │
# │ (Conv2D)          │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_se_expand │ (None, 1, 1,    │     1,008 │ block2b_se_re… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_se_excite │ (None, 56, 56,  │         0 │ block2b_activ… │   -   │
# │ (Multiply)        │ 144)            │           │ block2b_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_project_… │ (None, 56, 56,  │     3,456 │ block2b_se_ex… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_project_… │ (None, 56, 56,  │        96 │ block2b_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_drop      │ (None, 56, 56,  │         0 │ block2b_proje… │   -   │
# │ (Dropout)         │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_add (Add) │ (None, 56, 56,  │         0 │ block2b_drop[… │   -   │
# │                   │ 24)             │           │ block2a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_expand_c… │ (None, 56, 56,  │     3,456 │ block2b_add[0… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_expand_bn │ (None, 56, 56,  │       576 │ block3a_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_expand_a… │ (None, 56, 56,  │         0 │ block3a_expan… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_dwconv_p… │ (None, 59, 59,  │         0 │ block3a_expan… │   -   │
# │ (ZeroPadding2D)   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_dwconv    │ (None, 28, 28,  │     3,600 │ block3a_dwcon… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_bn        │ (None, 28, 28,  │       576 │ block3a_dwcon… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_activati… │ (None, 28, 28,  │         0 │ block3a_bn[0]… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_se_squee… │ (None, 144)     │         0 │ block3a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_se_resha… │ (None, 1, 1,    │         0 │ block3a_se_sq… │   -   │
# │ (Reshape)         │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_se_reduce │ (None, 1, 1, 6) │       870 │ block3a_se_re… │   N   │
# │ (Conv2D)          │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_se_expand │ (None, 1, 1,    │     1,008 │ block3a_se_re… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_se_excite │ (None, 28, 28,  │         0 │ block3a_activ… │   -   │
# │ (Multiply)        │ 144)            │           │ block3a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_project_… │ (None, 28, 28,  │     5,760 │ block3a_se_ex… │   N   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_project_… │ (None, 28, 28,  │       160 │ block3a_proje… │   N   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_expand_c… │ (None, 28, 28,  │     9,600 │ block3a_proje… │   N   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_expand_bn │ (None, 28, 28,  │       960 │ block3b_expan… │   N   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_expand_a… │ (None, 28, 28,  │         0 │ block3b_expan… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_dwconv    │ (None, 28, 28,  │     6,000 │ block3b_expan… │   N   │
# │ (DepthwiseConv2D) │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_bn        │ (None, 28, 28,  │       960 │ block3b_dwcon… │   N   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_activati… │ (None, 28, 28,  │         0 │ block3b_bn[0]… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_se_squee… │ (None, 240)     │         0 │ block3b_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_se_resha… │ (None, 1, 1,    │         0 │ block3b_se_sq… │   -   │
# │ (Reshape)         │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_se_reduce │ (None, 1, 1,    │     2,410 │ block3b_se_re… │   N   │
# │ (Conv2D)          │ 10)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_se_expand │ (None, 1, 1,    │     2,640 │ block3b_se_re… │   N   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_se_excite │ (None, 28, 28,  │         0 │ block3b_activ… │   -   │
# │ (Multiply)        │ 240)            │           │ block3b_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_project_… │ (None, 28, 28,  │     9,600 │ block3b_se_ex… │   N   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_project_… │ (None, 28, 28,  │       160 │ block3b_proje… │   N   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_drop      │ (None, 28, 28,  │         0 │ block3b_proje… │   -   │
# │ (Dropout)         │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_add (Add) │ (None, 28, 28,  │         0 │ block3b_drop[… │   -   │
# │                   │ 40)             │           │ block3a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_expand_c… │ (None, 28, 28,  │     9,600 │ block3b_add[0… │   N   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_expand_bn │ (None, 28, 28,  │       960 │ block4a_expan… │   N   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_expand_a… │ (None, 28, 28,  │         0 │ block4a_expan… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_dwconv_p… │ (None, 29, 29,  │         0 │ block4a_expan… │   -   │
# │ (ZeroPadding2D)   │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_dwconv    │ (None, 14, 14,  │     2,160 │ block4a_dwcon… │   N   │
# │ (DepthwiseConv2D) │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_bn        │ (None, 14, 14,  │       960 │ block4a_dwcon… │   N   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_activati… │ (None, 14, 14,  │         0 │ block4a_bn[0]… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_se_squee… │ (None, 240)     │         0 │ block4a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_se_resha… │ (None, 1, 1,    │         0 │ block4a_se_sq… │   -   │
# │ (Reshape)         │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_se_reduce │ (None, 1, 1,    │     2,410 │ block4a_se_re… │   N   │
# │ (Conv2D)          │ 10)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_se_expand │ (None, 1, 1,    │     2,640 │ block4a_se_re… │   N   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_se_excite │ (None, 14, 14,  │         0 │ block4a_activ… │   -   │
# │ (Multiply)        │ 240)            │           │ block4a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_project_… │ (None, 14, 14,  │    19,200 │ block4a_se_ex… │   N   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_project_… │ (None, 14, 14,  │       320 │ block4a_proje… │   N   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_expand_c… │ (None, 14, 14,  │    38,400 │ block4a_proje… │   N   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_expand_bn │ (None, 14, 14,  │     1,920 │ block4b_expan… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_expand_a… │ (None, 14, 14,  │         0 │ block4b_expan… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_dwconv    │ (None, 14, 14,  │     4,320 │ block4b_expan… │   N   │
# │ (DepthwiseConv2D) │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_bn        │ (None, 14, 14,  │     1,920 │ block4b_dwcon… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_activati… │ (None, 14, 14,  │         0 │ block4b_bn[0]… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_se_squee… │ (None, 480)     │         0 │ block4b_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_se_resha… │ (None, 1, 1,    │         0 │ block4b_se_sq… │   -   │
# │ (Reshape)         │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_se_reduce │ (None, 1, 1,    │     9,620 │ block4b_se_re… │   N   │
# │ (Conv2D)          │ 20)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_se_expand │ (None, 1, 1,    │    10,080 │ block4b_se_re… │   N   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_se_excite │ (None, 14, 14,  │         0 │ block4b_activ… │   -   │
# │ (Multiply)        │ 480)            │           │ block4b_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_project_… │ (None, 14, 14,  │    38,400 │ block4b_se_ex… │   N   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_project_… │ (None, 14, 14,  │       320 │ block4b_proje… │   N   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_drop      │ (None, 14, 14,  │         0 │ block4b_proje… │   -   │
# │ (Dropout)         │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_add (Add) │ (None, 14, 14,  │         0 │ block4b_drop[… │   -   │
# │                   │ 80)             │           │ block4a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_expand_c… │ (None, 14, 14,  │    38,400 │ block4b_add[0… │   N   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_expand_bn │ (None, 14, 14,  │     1,920 │ block4c_expan… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_expand_a… │ (None, 14, 14,  │         0 │ block4c_expan… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_dwconv    │ (None, 14, 14,  │     4,320 │ block4c_expan… │   N   │
# │ (DepthwiseConv2D) │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_bn        │ (None, 14, 14,  │     1,920 │ block4c_dwcon… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_activati… │ (None, 14, 14,  │         0 │ block4c_bn[0]… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_se_squee… │ (None, 480)     │         0 │ block4c_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_se_resha… │ (None, 1, 1,    │         0 │ block4c_se_sq… │   -   │
# │ (Reshape)         │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_se_reduce │ (None, 1, 1,    │     9,620 │ block4c_se_re… │   N   │
# │ (Conv2D)          │ 20)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_se_expand │ (None, 1, 1,    │    10,080 │ block4c_se_re… │   N   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_se_excite │ (None, 14, 14,  │         0 │ block4c_activ… │   -   │
# │ (Multiply)        │ 480)            │           │ block4c_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_project_… │ (None, 14, 14,  │    38,400 │ block4c_se_ex… │   N   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_project_… │ (None, 14, 14,  │       320 │ block4c_proje… │   N   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_drop      │ (None, 14, 14,  │         0 │ block4c_proje… │   -   │
# │ (Dropout)         │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_add (Add) │ (None, 14, 14,  │         0 │ block4c_drop[… │   -   │
# │                   │ 80)             │           │ block4b_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_expand_c… │ (None, 14, 14,  │    38,400 │ block4c_add[0… │   N   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_expand_bn │ (None, 14, 14,  │     1,920 │ block5a_expan… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_expand_a… │ (None, 14, 14,  │         0 │ block5a_expan… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_dwconv    │ (None, 14, 14,  │    12,000 │ block5a_expan… │   N   │
# │ (DepthwiseConv2D) │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_bn        │ (None, 14, 14,  │     1,920 │ block5a_dwcon… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_activati… │ (None, 14, 14,  │         0 │ block5a_bn[0]… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_se_squee… │ (None, 480)     │         0 │ block5a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_se_resha… │ (None, 1, 1,    │         0 │ block5a_se_sq… │   -   │
# │ (Reshape)         │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_se_reduce │ (None, 1, 1,    │     9,620 │ block5a_se_re… │   N   │
# │ (Conv2D)          │ 20)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_se_expand │ (None, 1, 1,    │    10,080 │ block5a_se_re… │   N   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_se_excite │ (None, 14, 14,  │         0 │ block5a_activ… │   -   │
# │ (Multiply)        │ 480)            │           │ block5a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_project_… │ (None, 14, 14,  │    53,760 │ block5a_se_ex… │   N   │
# │ (Conv2D)          │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_project_… │ (None, 14, 14,  │       448 │ block5a_proje… │   N   │
# │ (BatchNormalizat… │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_expand_c… │ (None, 14, 14,  │    75,264 │ block5a_proje… │   N   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_expand_bn │ (None, 14, 14,  │     2,688 │ block5b_expan… │   N   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_expand_a… │ (None, 14, 14,  │         0 │ block5b_expan… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_dwconv    │ (None, 14, 14,  │    16,800 │ block5b_expan… │   N   │
# │ (DepthwiseConv2D) │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_bn        │ (None, 14, 14,  │     2,688 │ block5b_dwcon… │   N   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_activati… │ (None, 14, 14,  │         0 │ block5b_bn[0]… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_se_squee… │ (None, 672)     │         0 │ block5b_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_se_resha… │ (None, 1, 1,    │         0 │ block5b_se_sq… │   -   │
# │ (Reshape)         │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_se_reduce │ (None, 1, 1,    │    18,844 │ block5b_se_re… │   N   │
# │ (Conv2D)          │ 28)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_se_expand │ (None, 1, 1,    │    19,488 │ block5b_se_re… │   N   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_se_excite │ (None, 14, 14,  │         0 │ block5b_activ… │   -   │
# │ (Multiply)        │ 672)            │           │ block5b_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_project_… │ (None, 14, 14,  │    75,264 │ block5b_se_ex… │   N   │
# │ (Conv2D)          │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_project_… │ (None, 14, 14,  │       448 │ block5b_proje… │   N   │
# │ (BatchNormalizat… │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_drop      │ (None, 14, 14,  │         0 │ block5b_proje… │   -   │
# │ (Dropout)         │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_add (Add) │ (None, 14, 14,  │         0 │ block5b_drop[… │   -   │
# │                   │ 112)            │           │ block5a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_expand_c… │ (None, 14, 14,  │    75,264 │ block5b_add[0… │   N   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_expand_bn │ (None, 14, 14,  │     2,688 │ block5c_expan… │   N   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_expand_a… │ (None, 14, 14,  │         0 │ block5c_expan… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_dwconv    │ (None, 14, 14,  │    16,800 │ block5c_expan… │   N   │
# │ (DepthwiseConv2D) │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_bn        │ (None, 14, 14,  │     2,688 │ block5c_dwcon… │   N   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_activati… │ (None, 14, 14,  │         0 │ block5c_bn[0]… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_se_squee… │ (None, 672)     │         0 │ block5c_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_se_resha… │ (None, 1, 1,    │         0 │ block5c_se_sq… │   -   │
# │ (Reshape)         │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_se_reduce │ (None, 1, 1,    │    18,844 │ block5c_se_re… │   N   │
# │ (Conv2D)          │ 28)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_se_expand │ (None, 1, 1,    │    19,488 │ block5c_se_re… │   N   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_se_excite │ (None, 14, 14,  │         0 │ block5c_activ… │   -   │
# │ (Multiply)        │ 672)            │           │ block5c_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_project_… │ (None, 14, 14,  │    75,264 │ block5c_se_ex… │   N   │
# │ (Conv2D)          │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_project_… │ (None, 14, 14,  │       448 │ block5c_proje… │   N   │
# │ (BatchNormalizat… │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_drop      │ (None, 14, 14,  │         0 │ block5c_proje… │   -   │
# │ (Dropout)         │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_add (Add) │ (None, 14, 14,  │         0 │ block5c_drop[… │   -   │
# │                   │ 112)            │           │ block5b_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_expand_c… │ (None, 14, 14,  │    75,264 │ block5c_add[0… │   N   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_expand_bn │ (None, 14, 14,  │     2,688 │ block6a_expan… │   N   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_expand_a… │ (None, 14, 14,  │         0 │ block6a_expan… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_dwconv_p… │ (None, 17, 17,  │         0 │ block6a_expan… │   -   │
# │ (ZeroPadding2D)   │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_dwconv    │ (None, 7, 7,    │    16,800 │ block6a_dwcon… │   N   │
# │ (DepthwiseConv2D) │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_bn        │ (None, 7, 7,    │     2,688 │ block6a_dwcon… │   N   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_activati… │ (None, 7, 7,    │         0 │ block6a_bn[0]… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_se_squee… │ (None, 672)     │         0 │ block6a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_se_resha… │ (None, 1, 1,    │         0 │ block6a_se_sq… │   -   │
# │ (Reshape)         │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_se_reduce │ (None, 1, 1,    │    18,844 │ block6a_se_re… │   N   │
# │ (Conv2D)          │ 28)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_se_expand │ (None, 1, 1,    │    19,488 │ block6a_se_re… │   N   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_se_excite │ (None, 7, 7,    │         0 │ block6a_activ… │   -   │
# │ (Multiply)        │ 672)            │           │ block6a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_project_… │ (None, 7, 7,    │   129,024 │ block6a_se_ex… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_project_… │ (None, 7, 7,    │       768 │ block6a_proje… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_expand_c… │ (None, 7, 7,    │   221,184 │ block6a_proje… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_expand_bn │ (None, 7, 7,    │     4,608 │ block6b_expan… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_expand_a… │ (None, 7, 7,    │         0 │ block6b_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_dwconv    │ (None, 7, 7,    │    28,800 │ block6b_expan… │   N   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_bn        │ (None, 7, 7,    │     4,608 │ block6b_dwcon… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_activati… │ (None, 7, 7,    │         0 │ block6b_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_se_squee… │ (None, 1152)    │         0 │ block6b_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_se_resha… │ (None, 1, 1,    │         0 │ block6b_se_sq… │   -   │
# │ (Reshape)         │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_se_reduce │ (None, 1, 1,    │    55,344 │ block6b_se_re… │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_se_expand │ (None, 1, 1,    │    56,448 │ block6b_se_re… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_se_excite │ (None, 7, 7,    │         0 │ block6b_activ… │   -   │
# │ (Multiply)        │ 1152)           │           │ block6b_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_project_… │ (None, 7, 7,    │   221,184 │ block6b_se_ex… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_project_… │ (None, 7, 7,    │       768 │ block6b_proje… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_drop      │ (None, 7, 7,    │         0 │ block6b_proje… │   -   │
# │ (Dropout)         │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_add (Add) │ (None, 7, 7,    │         0 │ block6b_drop[… │   -   │
# │                   │ 192)            │           │ block6a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_expand_c… │ (None, 7, 7,    │   221,184 │ block6b_add[0… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_expand_bn │ (None, 7, 7,    │     4,608 │ block6c_expan… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_expand_a… │ (None, 7, 7,    │         0 │ block6c_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_dwconv    │ (None, 7, 7,    │    28,800 │ block6c_expan… │   N   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_bn        │ (None, 7, 7,    │     4,608 │ block6c_dwcon… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_activati… │ (None, 7, 7,    │         0 │ block6c_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_se_squee… │ (None, 1152)    │         0 │ block6c_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_se_resha… │ (None, 1, 1,    │         0 │ block6c_se_sq… │   -   │
# │ (Reshape)         │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_se_reduce │ (None, 1, 1,    │    55,344 │ block6c_se_re… │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_se_expand │ (None, 1, 1,    │    56,448 │ block6c_se_re… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_se_excite │ (None, 7, 7,    │         0 │ block6c_activ… │   -   │
# │ (Multiply)        │ 1152)           │           │ block6c_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_project_… │ (None, 7, 7,    │   221,184 │ block6c_se_ex… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_project_… │ (None, 7, 7,    │       768 │ block6c_proje… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_drop      │ (None, 7, 7,    │         0 │ block6c_proje… │   -   │
# │ (Dropout)         │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_add (Add) │ (None, 7, 7,    │         0 │ block6c_drop[… │   -   │
# │                   │ 192)            │           │ block6b_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_expand_c… │ (None, 7, 7,    │   221,184 │ block6c_add[0… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_expand_bn │ (None, 7, 7,    │     4,608 │ block6d_expan… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_expand_a… │ (None, 7, 7,    │         0 │ block6d_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_dwconv    │ (None, 7, 7,    │    28,800 │ block6d_expan… │   N   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_bn        │ (None, 7, 7,    │     4,608 │ block6d_dwcon… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_activati… │ (None, 7, 7,    │         0 │ block6d_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_se_squee… │ (None, 1152)    │         0 │ block6d_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_se_resha… │ (None, 1, 1,    │         0 │ block6d_se_sq… │   -   │
# │ (Reshape)         │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_se_reduce │ (None, 1, 1,    │    55,344 │ block6d_se_re… │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_se_expand │ (None, 1, 1,    │    56,448 │ block6d_se_re… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_se_excite │ (None, 7, 7,    │         0 │ block6d_activ… │   -   │
# │ (Multiply)        │ 1152)           │           │ block6d_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_project_… │ (None, 7, 7,    │   221,184 │ block6d_se_ex… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_project_… │ (None, 7, 7,    │       768 │ block6d_proje… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_drop      │ (None, 7, 7,    │         0 │ block6d_proje… │   -   │
# │ (Dropout)         │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_add (Add) │ (None, 7, 7,    │         0 │ block6d_drop[… │   -   │
# │                   │ 192)            │           │ block6c_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_expand_c… │ (None, 7, 7,    │   221,184 │ block6d_add[0… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_expand_bn │ (None, 7, 7,    │     4,608 │ block7a_expan… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_expand_a… │ (None, 7, 7,    │         0 │ block7a_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_dwconv    │ (None, 7, 7,    │    10,368 │ block7a_expan… │   N   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_bn        │ (None, 7, 7,    │     4,608 │ block7a_dwcon… │   N   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_activati… │ (None, 7, 7,    │         0 │ block7a_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_se_squee… │ (None, 1152)    │         0 │ block7a_activ… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_se_resha… │ (None, 1, 1,    │         0 │ block7a_se_sq… │   -   │
# │ (Reshape)         │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_se_reduce │ (None, 1, 1,    │    55,344 │ block7a_se_re… │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_se_expand │ (None, 1, 1,    │    56,448 │ block7a_se_re… │   N   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_se_excite │ (None, 7, 7,    │         0 │ block7a_activ… │   -   │
# │ (Multiply)        │ 1152)           │           │ block7a_se_ex… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_project_… │ (None, 7, 7,    │   368,640 │ block7a_se_ex… │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_project_… │ (None, 7, 7,    │     1,280 │ block7a_proje… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ top_conv (Conv2D) │ (None, 7, 7,    │   409,600 │ block7a_proje… │   N   │
# │                   │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ top_bn            │ (None, 7, 7,    │     5,120 │ top_conv[0][0] │   N   │
# │ (BatchNormalizat… │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ top_activation    │ (None, 7, 7,    │         0 │ top_bn[0][0]   │   -   │
# │ (Activation)      │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 1280)    │         0 │ top_activatio… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_7 (Dense)   │ (None, 20)      │    25,620 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 4,075,191 (15.55 MB)
#  Trainable params: 25,620 (100.08 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 481ms/step
# Accuracy: 0.0460

# %% [markdown]
# # 9. DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

denseNet121_test = preprocess_input(x_test)
base_model_denseNet121 = DenseNet121(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_denseNet121.trainable = False

x = base_model_denseNet121.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_denseNet121 = Model(inputs=base_model_denseNet121.input, outputs=output, name="DenseNet121")

model_denseNet121.summary(show_trainable=True)

y_pred_probs = model_denseNet121.predict(denseNet121_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_denseNet121 = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_denseNet121:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step
# Model: "DenseNet121"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_8     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d    │ (None, 230,     │         0 │ input_layer_8… │   -   │
# │ (ZeroPadding2D)   │ 230, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_conv        │ (None, 112,     │     9,408 │ zero_padding2… │   N   │
# │ (Conv2D)          │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_bn          │ (None, 112,     │       256 │ conv1_conv[0]… │   N   │
# │ (BatchNormalizat… │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_relu        │ (None, 112,     │         0 │ conv1_bn[0][0] │   -   │
# │ (Activation)      │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_1  │ (None, 114,     │         0 │ conv1_relu[0]… │   -   │
# │ (ZeroPadding2D)   │ 114, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1             │ (None, 56, 56,  │         0 │ zero_padding2… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_bn │ (None, 56, 56,  │       256 │ pool1[0][0]    │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_c… │ (None, 56, 56,  │     8,192 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_bn │ (None, 56, 56,  │       512 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_con… │ (None, 56, 56,  │         0 │ pool1[0][0],   │   -   │
# │ (Concatenate)     │ 96)             │           │ conv2_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_0_bn │ (None, 56, 56,  │       384 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_0_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_c… │ (None, 56, 56,  │    12,288 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_bn │ (None, 56, 56,  │       512 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_con… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Concatenate)     │ 128)            │           │ conv2_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_0_bn │ (None, 56, 56,  │       512 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_0_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_c… │ (None, 56, 56,  │    16,384 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_bn │ (None, 56, 56,  │       512 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_con… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Concatenate)     │ 160)            │           │ conv2_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_0_bn │ (None, 56, 56,  │       640 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_0_r… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_c… │ (None, 56, 56,  │    20,480 │ conv2_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_bn │ (None, 56, 56,  │       512 │ conv2_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_r… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_con… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Concatenate)     │ 192)            │           │ conv2_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_0_bn │ (None, 56, 56,  │       768 │ conv2_block4_… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_0_r… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_c… │ (None, 56, 56,  │    24,576 │ conv2_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_bn │ (None, 56, 56,  │       512 │ conv2_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_r… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_con… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Concatenate)     │ 224)            │           │ conv2_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_0_bn │ (None, 56, 56,  │       896 │ conv2_block5_… │   N   │
# │ (BatchNormalizat… │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_0_r… │ (None, 56, 56,  │         0 │ conv2_block6_… │   -   │
# │ (Activation)      │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_c… │ (None, 56, 56,  │    28,672 │ conv2_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_bn │ (None, 56, 56,  │       512 │ conv2_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_r… │ (None, 56, 56,  │         0 │ conv2_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_con… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Concatenate)     │ 256)            │           │ conv2_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_bn          │ (None, 56, 56,  │     1,024 │ conv2_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_relu        │ (None, 56, 56,  │         0 │ pool2_bn[0][0] │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_conv        │ (None, 56, 56,  │    32,768 │ pool2_relu[0]… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_pool        │ (None, 28, 28,  │         0 │ pool2_conv[0]… │   -   │
# │ (AveragePooling2… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_bn │ (None, 28, 28,  │       512 │ pool2_pool[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_c… │ (None, 28, 28,  │    16,384 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_con… │ (None, 28, 28,  │         0 │ pool2_pool[0]… │   -   │
# │ (Concatenate)     │ 160)            │           │ conv3_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_0_bn │ (None, 28, 28,  │       640 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_0_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_c… │ (None, 28, 28,  │    20,480 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_con… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Concatenate)     │ 192)            │           │ conv3_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_0_bn │ (None, 28, 28,  │       768 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_0_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_c… │ (None, 28, 28,  │    24,576 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_con… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Concatenate)     │ 224)            │           │ conv3_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_0_bn │ (None, 28, 28,  │       896 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_0_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_c… │ (None, 28, 28,  │    28,672 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_con… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Concatenate)     │ 256)            │           │ conv3_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_0_bn │ (None, 28, 28,  │     1,024 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_0_r… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_c… │ (None, 28, 28,  │    32,768 │ conv3_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_bn │ (None, 28, 28,  │       512 │ conv3_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_r… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_con… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Concatenate)     │ 288)            │           │ conv3_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_0_bn │ (None, 28, 28,  │     1,152 │ conv3_block5_… │   N   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_0_r… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Activation)      │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_c… │ (None, 28, 28,  │    36,864 │ conv3_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_bn │ (None, 28, 28,  │       512 │ conv3_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_r… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_con… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Concatenate)     │ 320)            │           │ conv3_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_0_bn │ (None, 28, 28,  │     1,280 │ conv3_block6_… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_0_r… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_c… │ (None, 28, 28,  │    40,960 │ conv3_block7_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_bn │ (None, 28, 28,  │       512 │ conv3_block7_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_r… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block7_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_con… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Concatenate)     │ 352)            │           │ conv3_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_0_bn │ (None, 28, 28,  │     1,408 │ conv3_block7_… │   N   │
# │ (BatchNormalizat… │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_0_r… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Activation)      │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_c… │ (None, 28, 28,  │    45,056 │ conv3_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_bn │ (None, 28, 28,  │       512 │ conv3_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_r… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_con… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Concatenate)     │ 384)            │           │ conv3_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_0_bn │ (None, 28, 28,  │     1,536 │ conv3_block8_… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_0_r… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_c… │ (None, 28, 28,  │    49,152 │ conv3_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_bn │ (None, 28, 28,  │       512 │ conv3_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_r… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_con… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Concatenate)     │ 416)            │           │ conv3_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_0_… │ (None, 28, 28,  │     1,664 │ conv3_block9_… │   N   │
# │ (BatchNormalizat… │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_0_… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Activation)      │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │    53,248 │ conv3_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │       512 │ conv3_block10… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_2_… │ (None, 28, 28,  │    36,864 │ conv3_block10… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_co… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Concatenate)     │ 448)            │           │ conv3_block10… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_0_… │ (None, 28, 28,  │     1,792 │ conv3_block10… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_0_… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │    57,344 │ conv3_block11… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │       512 │ conv3_block11… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_2_… │ (None, 28, 28,  │    36,864 │ conv3_block11… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_co… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Concatenate)     │ 480)            │           │ conv3_block11… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_0_… │ (None, 28, 28,  │     1,920 │ conv3_block11… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_0_… │ (None, 28, 28,  │         0 │ conv3_block12… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │    61,440 │ conv3_block12… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │       512 │ conv3_block12… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │         0 │ conv3_block12… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_2_… │ (None, 28, 28,  │    36,864 │ conv3_block12… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_co… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Concatenate)     │ 512)            │           │ conv3_block12… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_bn          │ (None, 28, 28,  │     2,048 │ conv3_block12… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_relu        │ (None, 28, 28,  │         0 │ pool3_bn[0][0] │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_conv        │ (None, 28, 28,  │   131,072 │ pool3_relu[0]… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_pool        │ (None, 14, 14,  │         0 │ pool3_conv[0]… │   -   │
# │ (AveragePooling2… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_bn │ (None, 14, 14,  │     1,024 │ pool3_pool[0]… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_c… │ (None, 14, 14,  │    32,768 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_bn │ (None, 14, 14,  │       512 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_con… │ (None, 14, 14,  │         0 │ pool3_pool[0]… │   -   │
# │ (Concatenate)     │ 288)            │           │ conv4_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_0_bn │ (None, 14, 14,  │     1,152 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_0_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_c… │ (None, 14, 14,  │    36,864 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_bn │ (None, 14, 14,  │       512 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_con… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Concatenate)     │ 320)            │           │ conv4_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_0_bn │ (None, 14, 14,  │     1,280 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_0_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_c… │ (None, 14, 14,  │    40,960 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_bn │ (None, 14, 14,  │       512 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_con… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Concatenate)     │ 352)            │           │ conv4_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_0_bn │ (None, 14, 14,  │     1,408 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_0_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_c… │ (None, 14, 14,  │    45,056 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_bn │ (None, 14, 14,  │       512 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_con… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Concatenate)     │ 384)            │           │ conv4_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_0_bn │ (None, 14, 14,  │     1,536 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_0_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_c… │ (None, 14, 14,  │    49,152 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_bn │ (None, 14, 14,  │       512 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_con… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Concatenate)     │ 416)            │           │ conv4_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_0_bn │ (None, 14, 14,  │     1,664 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_0_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_c… │ (None, 14, 14,  │    53,248 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_bn │ (None, 14, 14,  │       512 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_con… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Concatenate)     │ 448)            │           │ conv4_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_0_bn │ (None, 14, 14,  │     1,792 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_0_r… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_c… │ (None, 14, 14,  │    57,344 │ conv4_block7_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_bn │ (None, 14, 14,  │       512 │ conv4_block7_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_r… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block7_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_con… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Concatenate)     │ 480)            │           │ conv4_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_0_bn │ (None, 14, 14,  │     1,920 │ conv4_block7_… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_0_r… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_c… │ (None, 14, 14,  │    61,440 │ conv4_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_bn │ (None, 14, 14,  │       512 │ conv4_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_r… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_con… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Concatenate)     │ 512)            │           │ conv4_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_0_bn │ (None, 14, 14,  │     2,048 │ conv4_block8_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_0_r… │ (None, 14, 14,  │         0 │ conv4_block9_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_c… │ (None, 14, 14,  │    65,536 │ conv4_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_bn │ (None, 14, 14,  │       512 │ conv4_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_r… │ (None, 14, 14,  │         0 │ conv4_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_con… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Concatenate)     │ 544)            │           │ conv4_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_0_… │ (None, 14, 14,  │     2,176 │ conv4_block9_… │   N   │
# │ (BatchNormalizat… │ 544)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_0_… │ (None, 14, 14,  │         0 │ conv4_block10… │   -   │
# │ (Activation)      │ 544)            │           │                │       │
# ...
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block7_con… │ (None, 7, 7,    │         0 │ conv5_block6_… │   -   │
# │ (Concatenate)     │ 736)            │           │ conv5_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_0_bn │ (None, 7, 7,    │     2,944 │ conv5_block7_… │   N   │
# │ (BatchNormalizat… │ 736)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_0_r… │ (None, 7, 7,    │         0 │ conv5_block8_… │   -   │
# │ (Activation)      │ 736)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_1_c… │ (None, 7, 7,    │    94,208 │ conv5_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_1_bn │ (None, 7, 7,    │       512 │ conv5_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_1_r… │ (None, 7, 7,    │         0 │ conv5_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_2_c… │ (None, 7, 7,    │    36,864 │ conv5_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_con… │ (None, 7, 7,    │         0 │ conv5_block7_… │   -   │
# │ (Concatenate)     │ 768)            │           │ conv5_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_0_bn │ (None, 7, 7,    │     3,072 │ conv5_block8_… │   N   │
# │ (BatchNormalizat… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_0_r… │ (None, 7, 7,    │         0 │ conv5_block9_… │   -   │
# │ (Activation)      │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_1_c… │ (None, 7, 7,    │    98,304 │ conv5_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_1_bn │ (None, 7, 7,    │       512 │ conv5_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_1_r… │ (None, 7, 7,    │         0 │ conv5_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_2_c… │ (None, 7, 7,    │    36,864 │ conv5_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_con… │ (None, 7, 7,    │         0 │ conv5_block8_… │   -   │
# │ (Concatenate)     │ 800)            │           │ conv5_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_0_… │ (None, 7, 7,    │     3,200 │ conv5_block9_… │   N   │
# │ (BatchNormalizat… │ 800)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_0_… │ (None, 7, 7,    │         0 │ conv5_block10… │   -   │
# │ (Activation)      │ 800)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_1_… │ (None, 7, 7,    │   102,400 │ conv5_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_1_… │ (None, 7, 7,    │       512 │ conv5_block10… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_1_… │ (None, 7, 7,    │         0 │ conv5_block10… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_2_… │ (None, 7, 7,    │    36,864 │ conv5_block10… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_co… │ (None, 7, 7,    │         0 │ conv5_block9_… │   -   │
# │ (Concatenate)     │ 832)            │           │ conv5_block10… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_0_… │ (None, 7, 7,    │     3,328 │ conv5_block10… │   N   │
# │ (BatchNormalizat… │ 832)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_0_… │ (None, 7, 7,    │         0 │ conv5_block11… │   -   │
# │ (Activation)      │ 832)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_1_… │ (None, 7, 7,    │   106,496 │ conv5_block11… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_1_… │ (None, 7, 7,    │       512 │ conv5_block11… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_1_… │ (None, 7, 7,    │         0 │ conv5_block11… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_2_… │ (None, 7, 7,    │    36,864 │ conv5_block11… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_co… │ (None, 7, 7,    │         0 │ conv5_block10… │   -   │
# │ (Concatenate)     │ 864)            │           │ conv5_block11… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_0_… │ (None, 7, 7,    │     3,456 │ conv5_block11… │   N   │
# │ (BatchNormalizat… │ 864)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_0_… │ (None, 7, 7,    │         0 │ conv5_block12… │   -   │
# │ (Activation)      │ 864)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_1_… │ (None, 7, 7,    │   110,592 │ conv5_block12… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_1_… │ (None, 7, 7,    │       512 │ conv5_block12… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_1_… │ (None, 7, 7,    │         0 │ conv5_block12… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_2_… │ (None, 7, 7,    │    36,864 │ conv5_block12… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_co… │ (None, 7, 7,    │         0 │ conv5_block11… │   -   │
# │ (Concatenate)     │ 896)            │           │ conv5_block12… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_0_… │ (None, 7, 7,    │     3,584 │ conv5_block12… │   N   │
# │ (BatchNormalizat… │ 896)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_0_… │ (None, 7, 7,    │         0 │ conv5_block13… │   -   │
# │ (Activation)      │ 896)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_1_… │ (None, 7, 7,    │   114,688 │ conv5_block13… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_1_… │ (None, 7, 7,    │       512 │ conv5_block13… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_1_… │ (None, 7, 7,    │         0 │ conv5_block13… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_2_… │ (None, 7, 7,    │    36,864 │ conv5_block13… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_co… │ (None, 7, 7,    │         0 │ conv5_block12… │   -   │
# │ (Concatenate)     │ 928)            │           │ conv5_block13… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_0_… │ (None, 7, 7,    │     3,712 │ conv5_block13… │   N   │
# │ (BatchNormalizat… │ 928)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_0_… │ (None, 7, 7,    │         0 │ conv5_block14… │   -   │
# │ (Activation)      │ 928)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_1_… │ (None, 7, 7,    │   118,784 │ conv5_block14… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_1_… │ (None, 7, 7,    │       512 │ conv5_block14… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_1_… │ (None, 7, 7,    │         0 │ conv5_block14… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_2_… │ (None, 7, 7,    │    36,864 │ conv5_block14… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_co… │ (None, 7, 7,    │         0 │ conv5_block13… │   -   │
# │ (Concatenate)     │ 960)            │           │ conv5_block14… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_0_… │ (None, 7, 7,    │     3,840 │ conv5_block14… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_0_… │ (None, 7, 7,    │         0 │ conv5_block15… │   -   │
# │ (Activation)      │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_1_… │ (None, 7, 7,    │   122,880 │ conv5_block15… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_1_… │ (None, 7, 7,    │       512 │ conv5_block15… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_1_… │ (None, 7, 7,    │         0 │ conv5_block15… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_2_… │ (None, 7, 7,    │    36,864 │ conv5_block15… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_co… │ (None, 7, 7,    │         0 │ conv5_block14… │   -   │
# │ (Concatenate)     │ 992)            │           │ conv5_block15… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_0_… │ (None, 7, 7,    │     3,968 │ conv5_block15… │   N   │
# │ (BatchNormalizat… │ 992)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_0_… │ (None, 7, 7,    │         0 │ conv5_block16… │   -   │
# │ (Activation)      │ 992)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_1_… │ (None, 7, 7,    │   126,976 │ conv5_block16… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_1_… │ (None, 7, 7,    │       512 │ conv5_block16… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_1_… │ (None, 7, 7,    │         0 │ conv5_block16… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_2_… │ (None, 7, 7,    │    36,864 │ conv5_block16… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_co… │ (None, 7, 7,    │         0 │ conv5_block15… │   -   │
# │ (Concatenate)     │ 1024)           │           │ conv5_block16… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bn                │ (None, 7, 7,    │     4,096 │ conv5_block16… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ relu (Activation) │ (None, 7, 7,    │         0 │ bn[0][0]       │   -   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 1024)    │         0 │ relu[0][0]     │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_8 (Dense)   │ (None, 20)      │    20,500 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 7,058,004 (26.92 MB)
#  Trainable params: 20,500 (80.08 KB)
#  Non-trainable params: 7,037,504 (26.85 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step
# Accuracy: 0.0580

# %% [markdown]
# # 10. NasNetMobile

# %%
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.applications.nasnet import preprocess_input
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.metrics import accuracy_score
import numpy as np
import random


SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

IMG_SIZE = 224
NUM_CLASSES = 20
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
y_train = y_train.flatten()
y_test = y_test.flatten()

selected_classes = random.sample(range(100), NUM_CLASSES)
class_map = {orig: new for new, orig in enumerate(selected_classes)}

test_mask = np.isin(y_test, selected_classes)
x_test, y_test = x_test[test_mask], y_test[test_mask]
y_test = np.vectorize(class_map.get)(y_test)

x_test = tf.image.resize(x_test, (IMG_SIZE, IMG_SIZE)).numpy()

nasaNetMobile_test = preprocess_input(x_test)
base_model_nasNetMobile = NASNetMobile(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model_nasNetMobile.trainable = False

x = base_model_nasNetMobile.output
x = GlobalAveragePooling2D()(x)
output = Dense(NUM_CLASSES, activation='softmax')(x)
model_nasNetMobile = Model(inputs=base_model_nasNetMobile.input, outputs=output, name="NASNetMobile")

model_nasNetMobile.summary(show_trainable=True)

y_pred_probs = model_nasNetMobile.predict(nasaNetMobile_test, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

acc_nasNetMobile = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc_nasNetMobile:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# Model: "NASNetMobile"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_9     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_conv1        │ (None, 111,     │       864 │ input_layer_9… │   N   │
# │ (Conv2D)          │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_bn1          │ (None, 111,     │       128 │ stem_conv1[0]… │   N   │
# │ (BatchNormalizat… │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_94     │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_conv_1… │ (None, 111,     │       352 │ activation_94… │   N   │
# │ (Conv2D)          │ 111, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_bn_1_s… │ (None, 111,     │        44 │ reduction_con… │   N   │
# │ (BatchNormalizat… │ 111, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_95     │ (None, 111,     │         0 │ reduction_bn_… │   -   │
# │ (Activation)      │ 111, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_97     │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 115,     │         0 │ activation_95… │   -   │
# │ (ZeroPadding2D)   │ 115, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 117,     │         0 │ activation_97… │   -   │
# │ (ZeroPadding2D)   │ 117, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │       396 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │     1,920 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_96     │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_98     │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       396 │ activation_96… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       660 │ activation_98… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_99     │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 117,     │         0 │ activation_99… │   -   │
# │ (ZeroPadding2D)   │ 117, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_101    │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_1_… │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 11)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │     1,920 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 115,     │         0 │ activation_10… │   -   │
# │ (ZeroPadding2D)   │ 115, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_103    │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │     1,152 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │       220 │ activation_10… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_100    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_pad_1_… │ (None, 113,     │         0 │ reduction_bn_… │   -   │
# │ (ZeroPadding2D)   │ 113, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       660 │ activation_10… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_102    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_104    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left2_… │ (None, 56, 56,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       396 │ activation_10… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       220 │ activation_10… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_relu_1_st… │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_2_… │ (None, 56, 56,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 11)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left3_… │ (None, 56, 56,  │         0 │ reduction_pad… │   -   │
# │ (AveragePooling2… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left4_… │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │ (AveragePooling2… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_right5… │ (None, 56, 56,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_2  │ (None, 112,     │         0 │ adjust_relu_1… │   -   │
# │ (ZeroPadding2D)   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add3_s… │ (None, 56, 56,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 11)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_12 (Add)      │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │                   │ 11)             │           │ reduction_lef… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add4_s… │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 11)             │           │ reduction_rig… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ cropping2d        │ (None, 111,     │         0 │ zero_padding2… │   -   │
# │ (Cropping2D)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_concat… │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │ (Concatenate)     │ 44)             │           │ reduction_add… │       │
# │                   │                 │           │ add_12[0][0],  │       │
# │                   │                 │           │ reduction_add… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 56, 56,  │         0 │ adjust_relu_1… │   -   │
# │ (AveragePooling2… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 56, 56,  │         0 │ cropping2d[0]… │   -   │
# │ (AveragePooling2… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_105    │ (None, 56, 56,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_1_st… │ (None, 56, 56,  │       352 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_2_st… │ (None, 56, 56,  │       352 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_conv_1… │ (None, 56, 56,  │       968 │ activation_10… │   N   │
# │ (Conv2D)          │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_2     │ (None, 56, 56,  │         0 │ adjust_conv_1… │   -   │
# │ (Concatenate)     │ 22)             │           │ adjust_conv_2… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_bn_1_s… │ (None, 56, 56,  │        88 │ reduction_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_stem_2  │ (None, 56, 56,  │        88 │ concatenate_2… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_106    │ (None, 56, 56,  │         0 │ reduction_bn_… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_108    │ (None, 56, 56,  │         0 │ adjust_bn_ste… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 59, 59,  │         0 │ activation_10… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 61, 61,  │         0 │ activation_10… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,034 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,562 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_107    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_109    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,034 │ activation_10… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,562 │ activation_10… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_110    │ (None, 56, 56,  │         0 │ adjust_bn_ste… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 61, 61,  │         0 │ activation_11… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_112    │ (None, 56, 56,  │         0 │ adjust_bn_ste… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_1_… │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 22)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,562 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 59, 59,  │         0 │ activation_11… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_114    │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,034 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       682 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_111    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_pad_1_… │ (None, 57, 57,  │         0 │ reduction_bn_… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,562 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_113    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_115    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left2_… │ (None, 28, 28,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,034 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       682 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_relu_1_0   │ (None, 56, 56,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_2_… │ (None, 28, 28,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 22)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left3_… │ (None, 28, 28,  │         0 │ reduction_pad… │   -   │
# │ (AveragePooling2… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left4_… │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │ (AveragePooling2… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_right5… │ (None, 28, 28,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_3  │ (None, 57, 57,  │         0 │ adjust_relu_1… │   -   │
# │ (ZeroPadding2D)   │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add3_s… │ (None, 28, 28,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 22)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_13 (Add)      │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │                   │ 22)             │           │ reduction_lef… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add4_s… │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 22)             │           │ reduction_rig… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ cropping2d_1      │ (None, 56, 56,  │         0 │ zero_padding2… │   -   │
# │ (Cropping2D)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_concat… │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │ (Concatenate)     │ 88)             │           │ reduction_add… │       │
# │                   │                 │           │ add_13[0][0],  │       │
# │                   │                 │           │ reduction_add… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 28, 28,  │         0 │ adjust_relu_1… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 28, 28,  │         0 │ cropping2d_1[… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_1_0   │ (None, 28, 28,  │       968 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_2_0   │ (None, 28, 28,  │       968 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_116    │ (None, 28, 28,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_3     │ (None, 28, 28,  │         0 │ adjust_conv_1… │   -   │
# │ (Concatenate)     │ 44)             │           │ adjust_conv_2… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_conv_1_0   │ (None, 28, 28,  │     3,872 │ activation_11… │   N   │
# │ (Conv2D)          │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_0       │ (None, 28, 28,  │       176 │ concatenate_3… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_bn_1_0     │ (None, 28, 28,  │       176 │ normal_conv_1… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_117    │ (None, 28, 28,  │         0 │ normal_bn_1_0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_119    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_121    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_123    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_125    │ (None, 28, 28,  │         0 │ normal_bn_1_0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_118    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_120    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_122    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_124    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_126    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_11… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_0    │ (None, 28, 28,  │         0 │ normal_bn_1_0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_0    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_0   │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_0    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_0    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_0    │ (None, 28, 28,  │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 44)             │           │ adjust_bn_0[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_0    │ (None, 28, 28,  │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 44)             │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_0    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ normal_bn_1_0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_0   │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Concatenate)     │ 264)            │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# │                   │                 │           │ normal_add_3_… │       │
# │                   │                 │           │ normal_add_4_… │       │
# │                   │                 │           │ normal_add_5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_127    │ (None, 28, 28,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_128    │ (None, 28, 28,  │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 264)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_proj… │ (None, 28, 28,  │     3,872 │ activation_12… │   N   │
# │ (Conv2D)          │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_conv_1_1   │ (None, 28, 28,  │    11,616 │ activation_12… │   N   │
# │ (Conv2D)          │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_1       │ (None, 28, 28,  │       176 │ adjust_conv_p… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_bn_1_1     │ (None, 28, 28,  │       176 │ normal_conv_1… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_129    │ (None, 28, 28,  │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_131    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_133    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_135    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_137    │ (None, 28, 28,  │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_12… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_130    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_132    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_134    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_136    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_138    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_13… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_1    │ (None, 28, 28,  │         0 │ normal_bn_1_1… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_1    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_1   │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_1    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_1    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_1    │ (None, 28, 28,  │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 44)             │           │ adjust_bn_1[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_1    │ (None, 28, 28,  │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 44)             │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_1    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ normal_bn_1_1… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# ...
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_26… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    35,376 │ activation_26… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_26… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_26… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_11   │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_11   │ (None, 7, 7,    │         0 │ adjust_bn_11[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_11  │ (None, 7, 7,    │         0 │ adjust_bn_11[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_11   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_11   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_11   │ (None, 7, 7,    │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 176)            │           │ adjust_bn_11[… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_11   │ (None, 7, 7,    │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 176)            │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_11   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ normal_bn_1_1… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_11  │ (None, 7, 7,    │         0 │ adjust_bn_11[… │   -   │
# │ (Concatenate)     │ 1056)           │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# │                   │                 │           │ normal_add_3_… │       │
# │                   │                 │           │ normal_add_4_… │       │
# │                   │                 │           │ normal_add_5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_269    │ (None, 7, 7,    │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 1056)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_270    │ (None, 7, 7,    │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 1056)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_proj… │ (None, 7, 7,    │   185,856 │ activation_26… │   N   │
# │ (Conv2D)          │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_conv_1_12  │ (None, 7, 7,    │   185,856 │ activation_27… │   N   │
# │ (Conv2D)          │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_12      │ (None, 7, 7,    │       704 │ adjust_conv_p… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_bn_1_12    │ (None, 7, 7,    │       704 │ normal_conv_1… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_271    │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_273    │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_275    │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_277    │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_279    │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    35,376 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    32,560 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    35,376 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    32,560 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    32,560 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_272    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_274    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_276    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_278    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_280    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    35,376 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    35,376 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_27… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_28… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_12   │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_12   │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_12  │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_12   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_12   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_12   │ (None, 7, 7,    │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 176)            │           │ adjust_bn_12[… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_12   │ (None, 7, 7,    │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 176)            │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_12   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ normal_bn_1_1… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_12  │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Concatenate)     │ 1056)           │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# │                   │                 │           │ normal_add_3_… │       │
# │                   │                 │           │ normal_add_4_… │       │
# │                   │                 │           │ normal_add_5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_281    │ (None, 7, 7,    │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 1056)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 1056)    │         0 │ activation_28… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_9 (Dense)   │ (None, 20)      │    21,140 │ global_averag… │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 4,290,856 (16.37 MB)
#  Trainable params: 21,140 (82.58 KB)
#  Non-trainable params: 4,269,716 (16.29 MB)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 484ms/step
# Accuracy: 0.0580

# %%
from collections import Counter
from tensorflow.keras.models import Model

models = [model_vgg16, model_vgg19, model_xception, model_resnet50, model_resnet50v2, model_inceptionv3, model_mobilenetV2, model_efficientNetB0, model_denseNet121, model_nasNetMobile]
model_names = ["VGG16", "VGG19", "Xception", "ResNet50", "ResNet50V2", "InceptionV3", "MobileNetV2", "EfficientNetB0", "DenseNet121", "NasNetMobile"]
model_acc = [acc_vgg16, acc_vgg19, acc_xception, acc_resnet50, acc_resnet50v2, acc_inceptionv3, acc_mobilenetv2, acc_efficientnetb0, acc_denseNet121, acc_nasNetMobile]

for model, name, acc in zip(models, model_names, model_acc):
    layer_types = [type(layer).__name__ for layer in model.layers]
    layer_type_counts = Counter(layer_types)

    print(f"\n{name} Accuracy score: {acc}")
    print(f"{name} Layer Type Counts:")
    for layer_type, count in layer_type_counts.items():
        print(f"{layer_type}: {count}")
# Out:
# VGG16 Accuracy score: 0.0895
# VGG16 Layer Type Counts:
# InputLayer: 1
# Conv2D: 13
# MaxPooling2D: 5
# GlobalAveragePooling2D: 1
# Dense: 1
#
# VGG19 Accuracy score: 0.031
# VGG19 Layer Type Counts:
# InputLayer: 1
# Conv2D: 16
# MaxPooling2D: 5
# GlobalAveragePooling2D: 1
# Dense: 1
#
# Xception Accuracy score: 0.052
# Xception Layer Type Counts:
# InputLayer: 1
# Conv2D: 6
# BatchNormalization: 40
# Activation: 35
# SeparableConv2D: 34
# MaxPooling2D: 4
# Add: 12
# GlobalAveragePooling2D: 1
# Dense: 1
#
# ResNet50 Accuracy score: 0.0725
# ResNet50 Layer Type Counts:
# InputLayer: 1
# ZeroPadding2D: 2
# Conv2D: 53
# BatchNormalization: 53
# Activation: 49
# MaxPooling2D: 1
# Add: 16
# GlobalAveragePooling2D: 1
# Dense: 1
#
# ResNet50V2 Accuracy score: 0.07
# ResNet50V2 Layer Type Counts:
# InputLayer: 1
# ZeroPadding2D: 18
# Conv2D: 53
# MaxPooling2D: 4
# BatchNormalization: 49
# Activation: 49
# Add: 16
# GlobalAveragePooling2D: 1
# Dense: 1
#
# InceptionV3 Accuracy score: 0.043
# InceptionV3 Layer Type Counts:
# InputLayer: 1
# Conv2D: 94
# BatchNormalization: 94
# Activation: 94
# MaxPooling2D: 4
# AveragePooling2D: 9
# Concatenate: 15
# GlobalAveragePooling2D: 1
# Dense: 1
#
# MobileNetV2 Accuracy score: 0.026
# MobileNetV2 Layer Type Counts:
# InputLayer: 1
# Conv2D: 35
# BatchNormalization: 52
# ReLU: 35
# DepthwiseConv2D: 17
# ZeroPadding2D: 4
# Add: 10
# GlobalAveragePooling2D: 1
# Dense: 1
#
# EfficientNetB0 Accuracy score: 0.046
# EfficientNetB0 Layer Type Counts:
# InputLayer: 1
# Rescaling: 2
# Normalization: 1
# ZeroPadding2D: 5
# Conv2D: 65
# BatchNormalization: 49
# Activation: 33
# DepthwiseConv2D: 16
# GlobalAveragePooling2D: 17
# Reshape: 16
# Multiply: 16
# Dropout: 9
# Add: 9
# Dense: 1
#
# DenseNet121 Accuracy score: 0.058
# DenseNet121 Layer Type Counts:
# InputLayer: 1
# ZeroPadding2D: 2
# Conv2D: 120
# BatchNormalization: 121
# Activation: 121
# MaxPooling2D: 1
# Concatenate: 58
# AveragePooling2D: 3
# GlobalAveragePooling2D: 1
# Dense: 1
#
# NasNetMobile Accuracy score: 0.039
# NasNetMobile Layer Type Counts:
# InputLayer: 1
# Conv2D: 36
# BatchNormalization: 192
# Activation: 192
# ZeroPadding2D: 24
# SeparableConv2D: 160
# Add: 80
# MaxPooling2D: 8
# AveragePooling2D: 52
# Cropping2D: 4
# Concatenate: 20
# GlobalAveragePooling2D: 1
# Dense: 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

accuracies = {
    'VGG16': 0.0895,
    'VGG19': 0.031,
    'Xception': 0.052,
    'ResNet50': 0.0725,
    'ResNet50V2': 0.07,
    'InceptionV3': 0.043,
    'MobileNetV2': 0.026,
    'EfficientNetB0': 0.046,
    'DenseNet121': 0.058,
    'NasNetMobile': 0.039
}

layer_counts = {
    'VGG16': {'Conv2D': 13, 'Dense': 1, 'MaxPooling2D': 5, 'GlobalAveragePooling2D': 1},
    'VGG19': {'Conv2D': 16, 'Dense': 1, 'MaxPooling2D': 5, 'GlobalAveragePooling2D': 1},
    'Xception': {'Conv2D': 6, 'SeparableConv2D': 34, 'BatchNormalization': 40, 'Activation': 35, 'Add': 12,
                 'MaxPooling2D': 4, 'GlobalAveragePooling2D': 1, 'Dense': 1},
    'ResNet50': {'Conv2D': 53, 'BatchNormalization': 53, 'Activation': 49, 'Add': 16,
                 'MaxPooling2D': 1, 'GlobalAveragePooling2D': 1, 'Dense': 1},
    'ResNet50V2': {'Conv2D': 53, 'BatchNormalization': 49, 'Activation': 49, 'Add': 16,
                   'MaxPooling2D': 4, 'GlobalAveragePooling2D': 1, 'Dense': 1},
    'InceptionV3': {'Conv2D': 94, 'BatchNormalization': 94, 'Activation': 94, 'Concatenate': 15,
                    'MaxPooling2D': 4, 'AveragePooling2D': 9, 'GlobalAveragePooling2D': 1, 'Dense': 1},
    'MobileNetV2': {'Conv2D': 35, 'DepthwiseConv2D': 17, 'ReLU': 35, 'BatchNormalization': 52, 'Add': 10,
                    'ZeroPadding2D': 4, 'GlobalAveragePooling2D': 1, 'Dense': 1},
    'EfficientNetB0': {'Conv2D': 65, 'BatchNormalization': 49, 'Activation': 33, 'Add': 9,
                       'GlobalAveragePooling2D': 17, 'Dense': 1},
    'DenseNet121': {'Conv2D': 120, 'BatchNormalization': 121, 'Activation': 121, 'Concatenate': 58,
                    'AveragePooling2D': 3, 'GlobalAveragePooling2D': 1, 'Dense': 1},
    'NasNetMobile': {'Conv2D': 36, 'SeparableConv2D': 160, 'BatchNormalization': 192, 'Activation': 192, 'Add': 80,
                     'AveragePooling2D': 52, 'Concatenate': 20, 'MaxPooling2D': 8, 'GlobalAveragePooling2D': 1, 'Dense': 1}
}

plt.figure(figsize=(12, 6))
sns.barplot(x=list(accuracies.keys()), y=list(accuracies.values()), palette="Blues_d")
plt.title("Model Accuracy Scores")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

flat_layer_data = []
for model, layers in layer_counts.items():
    for layer, count in layers.items():
        flat_layer_data.append({'Model': model, 'LayerType': layer, 'Count': count})

df_layers = pd.DataFrame(flat_layer_data)

plt.figure(figsize=(14, 7))
sns.barplot(data=df_layers, x='Model', y='Count', hue='LayerType')
plt.title("Layer Type Counts per Model")
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\12\AppData\Local\Temp\ipykernel_11876\643223892.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(accuracies.keys()), y=list(accuracies.values()), palette="Blues_d")

# %%
import numpy as np

def summarize_model_params(models, input_shape=(224, 224, 3)):
    for model in models:
        print(f"Model: {model.name}")

        param_count = model.count_params()
        print(f"Total Parameters: {param_count:,}")

        size_mb = param_count * 4 / (1024 ** 2)
        print(f"Estimated Size: {size_mb:.2f} MB")

        print("—" * 40)
        
summarize_model_params(models)
# Out:
# Model: VGG16
# Total Parameters: 14,724,948
# Estimated Size: 56.17 MB
# ————————————————————————————————————————
# Model: VGG19
# Total Parameters: 20,034,644
# Estimated Size: 76.43 MB
# ————————————————————————————————————————
# Model: Xception
# Total Parameters: 20,902,460
# Estimated Size: 79.74 MB
# ————————————————————————————————————————
# Model: ResNet50
# Total Parameters: 23,628,692
# Estimated Size: 90.14 MB
# ————————————————————————————————————————
# Model: ResNet50V2
# Total Parameters: 23,605,780
# Estimated Size: 90.05 MB
# ————————————————————————————————————————
# Model: InceptionV3
# Total Parameters: 21,843,764
# Estimated Size: 83.33 MB
# ————————————————————————————————————————
# Model: MobileNetV2
# Total Parameters: 2,283,604
# Estimated Size: 8.71 MB
# ————————————————————————————————————————
# Model: EfficientNetB0
# Total Parameters: 4,075,191
# Estimated Size: 15.55 MB
# ————————————————————————————————————————
# Model: DenseNet121
# Total Parameters: 7,058,004
# Estimated Size: 26.92 MB
# ————————————————————————————————————————
# Model: NASNetMobile
# Total Parameters: 4,290,856
# Estimated Size: 16.37 MB
# ————————————————————————————————————————

# %%
import matplotlib.pyplot as plt

model_names = [
    "VGG16", "VGG19", "Xception", "ResNet50", "ResNet50V2",
    "InceptionV3", "MobileNetV2", "EfficientNetB0", "DenseNet121", "NASNetMobile"
]
param_counts = [
    14724948, 20034644, 20902460, 23628692, 23605780,
    21843764, 2283604, 4075191, 7058004, 4290856
]
model_sizes = [
    56.17, 76.43, 79.74, 90.14, 90.05,
    83.33, 8.71, 15.55, 26.92, 16.37
]

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

color = 'tab:blue'
ax1.set_xlabel('Model Name')
ax1.set_ylabel('Model Size (MB)', color=color)
bars = ax1.bar(model_names, model_sizes, color=color, alpha=0.7, label='Model Size (MB)')
ax1.tick_params(axis='y', labelcolor=color)
plt.xticks(rotation=45)

# Annotate sizes
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2.0, yval + 1, f'{yval:.1f}MB', ha='center', va='bottom', fontsize=9)

# Create a second y-axis for parameter counts
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Parameter Count (millions)', color=color)
ax2.plot(model_names, [p / 1e6 for p in param_counts], color=color, marker='o', label='Parameters (M)')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('Model Size and Parameter Count Comparison')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Model": [
        "VGG16", "VGG19", "Xception", "ResNet50", "ResNet50V2", "InceptionV3",
        "MobileNetV2", "EfficientNetB0", "DenseNet121", "NASNetMobile"
    ],
    "Parameters (M)": [14.72, 20.03, 20.90, 23.63, 23.61, 21.84, 2.28, 4.08, 7.06, 4.29],
    "Size (MB)": [56.17, 76.43, 79.74, 90.14, 90.05, 83.33, 8.71, 15.55, 26.92, 16.37],
    "Accuracy (%)": [8.95, 3.10, 5.20, 7.25, 7.00, 4.30, 2.60, 4.60, 5.80, 3.90]
}

df = pd.DataFrame(data)

fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.bar(df['Model'], df['Parameters (M)'], label='Parameters (M)', alpha=0.7)
ax1.bar(df['Model'], df['Size (MB)'], bottom=df['Parameters (M)'], label='Size (MB)', alpha=0.7)
ax1.set_ylabel('Parameters / Size')
ax1.set_xlabel('Model')
ax1.tick_params(axis='x', rotation=45)

ax2 = ax1.twinx()
ax2.plot(df['Model'], df['Accuracy (%)'], color='red', marker='o', label='Accuracy (%)')
ax2.set_ylabel('Accuracy (%)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))
plt.title("Model Architecture Comparison: Parameters, Size and Accuracy")
plt.tight_layout()
plt.show()
